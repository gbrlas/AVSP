# %%
import json
import numpy as np
def load_json():
    
    authors = []
    features = []
    scores = []
    
    with open('dataset.json') as data_file:
        data = json.load(data_file)
        labels = data["column_descriptors"]
        author_data = data["author_data"]
        
        for author in author_data.keys():
            authors.append(author)
            features.append(author_data[author]['feature_vecs'])
            scores_str = author_data[author]['scores']
            scores.append(np.asarray([int(score_) for score_ in scores_str]))
    
    # features to numpy array
    features = [np.asarray(feature) for feature in features]
    
    return labels, authors, features, scores

# %%
labels, authors, features, scores = load_json()
print (authors[0], features[0].shape, scores[0].shape)
print (labels)
# Out:
# (u'bodmas', (3, 34), (3,))
# [u'number_of_modules', u'lines_of_code', u'lines_of_code_per_module', u'McCabes_cyclomatic_complexity', u'McCabes_cyclomatic_complexity_per_module', u'lines_of_comment', u'lines_of_comment_per_module', u'lines_of_code_per_line_of_comment', u'McCabes_cyclomatic_complexity_per_line_of_comment', u'IF4', u'IF4_per_module', u'IF4_visible', u'IF4_visible_per_module', u'IF4_concrete', u'IF4_concrete', u'rejected_lines_of_code\n', u'Files', u'Lines', u'AVG Len', u'Code', u'Comments', u'White SP', u'Cd/Cm+WS', u'Cd/Cm', u'Cd/WS', u'% Code', u'cnt_classes', u'max_member_funs', u'max_nested_loops', u'max_nesting_depth', u'max_params_in_decl', u'member_funs', u'member_vars', u'min_member_funs\n']

# %%
# training and test split
import random
cnt_train = int(0.8 * len(authors)) + 1

print (cnt_train)

train_authors_indices = set()

while len(train_authors_indices) < cnt_train:
    train_authors_indices.add(random.randint(0, len(authors) - 1))
    
test_authors_indices = set()

for i in range(len(authors)):
    if i not in train_authors_indices:
        test_authors_indices.add(i)

train_authors = [authors[i] for i in train_authors_indices]
        
test_authors = [authors[i] for i in test_authors_indices]

print(len(train_authors))
print(len(test_authors))
# Out:
# 1458
# 1458
# 364

# %%
X_train_list = []
y_train_list = []
X_test_list = []
y_test_list = []

for index in train_authors_indices:
    X_train_list.extend(features[index])
    y_train_list.extend(scores[index])
    
for index in test_authors_indices:
    X_test_list.extend(features[index])
    y_test_list.extend(scores[index])

X_train = np.asarray(X_train_list)
y_train = np.asarray(y_train_list)
X_test = np.asarray(X_test_list)
y_test = np.asarray(y_test_list)

print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# ((15206, 34), (15206,), (3461, 34), (3461,))

# %%
# y is vector of labels
def create_labels(y):
    y_l = np.copy(y)
    for i in range(y.shape[0]):
        if y[i] >= 80: 
            y_l[i] = 5
        if y[i] >= 60 and y[i] < 80: 
            y_l[i] = 4
        if y[i] >= 40 and y[i] < 60:
            y_l[i] = 3
        if y[i] >= 20 and y[i] < 40:
            y_l[i] = 2
        if y[i] < 20: 
            y_l[i] = 1
    return y_l

# %%
 # creating score labels for classifying
    
y_train = create_labels(y_train) 
y_test = create_labels(y_test)

# %%
from sklearn.neural_network import MLPClassifier

alphas = [0.0001, 0.001, 0.01, 0.1]
solvers = ["adam", "lbfgs", "sgd"]
learning_rates = ["constant", "adaptive", "invscaling"]

for alpha in alphas:
    print ("Alpha:\t", alpha)
    for solver in solvers:
        print ("\tSolver:\t", solver)
        for learning_rate in learning_rates:
            print ("\t\tLearning rate:\t", learning_rate, end="\t")
            mlpC = MLPClassifier(alpha=alpha, batch_size='auto', learning_rate=learning_rate, learning_rate_init=0.01, power_t=0.5, shuffle=True, max_iter=500)
            mlpC.fit(X_train, y_train)
            print ("MLPC Score:\t", mlpC.score(X_test, y_test))

# %%
from sklearn.ensemble import RandomForestClassifier

criterions = [ "gini", "entropy"]
estimators_size = [50, 100, 150, 200]

import sys
def printf(format, *args):
    sys.stdout.write(format % args)

for criterion in criterions:
    for n_estimators in estimators_size:
        printf("RFC\t%d estimators\t%s criterion\n", n_estimators, criterion)
        rfc = RandomForestClassifier(n_estimators=n_estimators, max_features='log2', criterion=criterion)
        rfc.fit(X_train, y_train)
        printf("Score:\t%f\n\n",rfc.score(X_test, y_test))
# Out:
# RFC	50 estimators	gini criterion
# Score:	0.692863
#
# RFC	100 estimators	gini criterion
# Score:	0.697775
#
# RFC	150 estimators	gini criterion
# Score:	0.694019
#
# RFC	200 estimators	gini criterion
# Score:	0.694886
#
# RFC	50 estimators	entropy criterion
# Score:	0.693730
#
# RFC	100 estimators	entropy criterion
# Score:	0.700376
#
# RFC	150 estimators	entropy criterion
# Score:	0.698931
#
# RFC	200 estimators	entropy criterion
# Score:	0.699798

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X_train, y_train)

print (clf.score(X_test, y_test))
# Out:
# 0.256284310893

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(X_train, y_train)
print (gbc.score(X_test, y_test))
# Out:
# 0.365501300202

# %%
from sklearn.ensemble import AdaBoostClassifier
abc = AdaBoostClassifier()
abc.fit(X_train, y_train)
print (abc.score(X_test, y_test))
# Out:
# 0.292112106328

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier(n_estimators=30)
etc.fit(X_train, y_train)
print (etc.score(X_test, y_test))
# Out:
# 0.700375613984

# %%
from sklearn import tree
dtc = tree.DecisionTreeClassifier()
dtc.fit(X_train, y_train)
print (dtc.score(X_test, y_test))
# Out:
# 0.684195319272

# %%
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    print ("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print ("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print ("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)

# %%
tree_to_code(dtc, labels)
# Out:
# def tree(number_of_modules, lines_of_code, lines_of_code_per_module, McCabes_cyclomatic_complexity, McCabes_cyclomatic_complexity_per_module, lines_of_comment, lines_of_comment_per_module, lines_of_code_per_line_of_comment, McCabes_cyclomatic_complexity_per_line_of_comment, IF4, IF4_per_module, IF4_visible, IF4_visible_per_module, IF4_concrete, IF4_concrete, rejected_lines_of_code
# , Files, Lines, AVG Len, Code, Comments, White SP, Cd/Cm+WS, Cd/Cm, Cd/WS, % Code, cnt_classes, max_member_funs, max_nested_loops, max_nesting_depth, max_params_in_decl, member_funs, member_vars, min_member_funs
# ):
#   if rejected_lines_of_code
#  <= 1.5:
#     if Comments <= 2.5:
#       if % Code <= 0.944999992847:
#         if lines_of_code_per_module <= 27.75:
#           if lines_of_code_per_module <= 22.75:
#             if max_params_in_decl <= 1.5:
#               if lines_of_code <= 40.5:
#                 if McCabes_cyclomatic_complexity <= 6.5:
#                   if Lines <= 19.5:
#                     if lines_of_code_per_module <= 13.5:
#                       if Cd/WS <= 4.5:
#                         if lines_of_code <= 12.5:
#                           if Code <= 9.5:
#                             if Lines <= 7.0:
#                               return [[ 1.  0.  0.  0.  0.]]
#                             else:  # if Lines > 7.0
#                               return [[ 0.  0.  0.  0.  2.]]
#                           else:  # if Code > 9.5
#                             if lines_of_comment <= 1.5:
#                               return [[ 0.  0.  8.  0.  0.]]
#                             else:  # if lines_of_comment > 1.5
#                               if max_nested_loops <= 1.5:
#                                 return [[ 0.  0.  0.  0.  2.]]
#                               else:  # if max_nested_loops > 1.5
#                                 return [[ 0.  0.  2.  0.  0.]]
#                         else:  # if lines_of_code > 12.5
#                           return [[ 0.  0.  0.  4.  0.]]
#                       else:  # if Cd/WS > 4.5
#                         if Cd/Cm+WS <= 4.83500003815:
#                           return [[ 0.  0.  0.  0.  8.]]
#                         else:  # if Cd/Cm+WS > 4.83500003815
#                           if AVG Len <= 15.5:
#                             if lines_of_code_per_module <= 12.5:
#                               if max_nesting_depth <= 1.5:
#                                 return [[ 1.  0.  0.  0.  0.]]
#                               else:  # if max_nesting_depth > 1.5
#                                 return [[ 0.  0.  0.  2.  0.]]
#                             else:  # if lines_of_code_per_module > 12.5
#                               return [[ 0.  0.  0.  0.  4.]]
#                           else:  # if AVG Len > 15.5
#                             if McCabes_cyclomatic_complexity_per_module <= 2.5:
#                               return [[ 0.  0.  2.  0.  0.]]
#                             else:  # if McCabes_cyclomatic_complexity_per_module > 2.5
#                               if max_nesting_depth <= 2.5:
#                                 if AVG Len <= 17.5:
#                                   return [[  0.  10.   0.   0.   0.]]
#                                 else:  # if AVG Len > 17.5
#                                   if Cd/WS <= 11.25:
#                                     return [[ 0.  0.  0.  0.  2.]]
#                                   else:  # if Cd/WS > 11.25
#                                     return [[ 0.  6.  0.  0.  0.]]
#                               else:  # if max_nesting_depth > 2.5
#                                 return [[ 0.  0.  0.  1.  0.]]
#                     else:  # if lines_of_code_per_module > 13.5
#                       if AVG Len <= 19.5:
#                         if McCabes_cyclomatic_complexity <= 3.5:
#                           if % Code <= 0.814999997616:
#                             return [[ 0.  0.  0.  0.  2.]]
#                           else:  # if % Code > 0.814999997616
#                             return [[  0.   0.   0.  24.   0.]]
#                         else:  # if McCabes_cyclomatic_complexity > 3.5
#                           if lines_of_code <= 15.5:
#                             return [[ 0.  0.  0.  0.  7.]]
#                           else:  # if lines_of_code > 15.5
#                             return [[ 0.  0.  0.  2.  0.]]
#                       else:  # if AVG Len > 19.5
#                         if Code <= 16.5:
#                           return [[ 0.  0.  0.  0.  7.]]
#                         else:  # if Code > 16.5
#                           if AVG Len <= 29.0:
#                             return [[ 0.  2.  0.  0.  0.]]
#                           else:  # if AVG Len > 29.0
#                             return [[ 0.  0.  0.  0.  2.]]
#                   else:  # if Lines > 19.5
#                     if Comments <= 1.5:
#                       if rejected_lines_of_code
#  <= 0.5:
#                         if Lines <= 21.5:
#                           if Lines <= 20.5:
#                             if lines_of_code <= 13.5:
#                               return [[ 0.  0.  0.  2.  0.]]
#                             else:  # if lines_of_code > 13.5
#                               return [[ 0.  0.  6.  0.  0.]]
#                           else:  # if Lines > 20.5
#                             return [[ 0.  0.  0.  6.  0.]]
#                         else:  # if Lines > 21.5
#                           if Code <= 20.5:
#                             if lines_of_code <= 14.5:
#                               return [[ 0.  4.  0.  0.  0.]]
#                             else:  # if lines_of_code > 14.5
#                               if lines_of_code_per_module <= 16.5:
#                                 return [[ 0.  0.  4.  0.  0.]]
#                               else:  # if lines_of_code_per_module > 16.5
#                                 if Cd/Cm+WS <= 7.375:
#                                   if Lines <= 24.0:
#                                     return [[ 1.  0.  0.  0.  0.]]
#                                   else:  # if Lines > 24.0
#                                     if lines_of_code_per_module <= 18.5:
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                     else:  # if lines_of_code_per_module > 18.5
#                                       return [[ 1.  0.  0.  0.  0.]]
#                                 else:  # if Cd/Cm+WS > 7.375
#                                   return [[ 0.  0.  2.  0.  0.]]
#                           else:  # if Code > 20.5
#                             if AVG Len <= 12.5:
#                               if Cd/WS <= 2.25:
#                                 return [[ 0.  0.  2.  0.  0.]]
#                               else:  # if Cd/WS > 2.25
#                                 return [[ 0.  0.  0.  0.  4.]]
#                             else:  # if AVG Len > 12.5
#                               if Cd/Cm <= 24.0:
#                                 if Code <= 21.5:
#                                   if AVG Len <= 16.5:
#                                     return [[ 0.  0.  0.  2.  0.]]
#                                   else:  # if AVG Len > 16.5
#                                     return [[ 0.  0.  5.  0.  0.]]
#                                 else:  # if Code > 21.5
#                                   return [[  0.   0.  16.   0.   0.]]
#                               else:  # if Cd/Cm > 24.0
#                                 return [[ 1.  0.  0.  0.  0.]]
#                       else:  # if rejected_lines_of_code
#  > 0.5
#                         if Cd/Cm+WS <= 7.83500003815:
#                           if Cd/WS <= 3.44000005722:
#                             if AVG Len <= 18.0:
#                               if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                 if max_params_in_decl <= 0.5:
#                                   return [[ 0.  8.  0.  0.  0.]]
#                                 else:  # if max_params_in_decl > 0.5
#                                   if Lines <= 31.5:
#                                     return [[ 0.  1.  0.  0.  0.]]
#                                   else:  # if Lines > 31.5
#                                     return [[ 1.  0.  0.  0.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                 if Cd/Cm+WS <= 2.71000003815:
#                                   if Code <= 20.5:
#                                     return [[ 0.  2.  0.  0.  0.]]
#                                   else:  # if Code > 20.5
#                                     if Code <= 23.5:
#                                       return [[ 0.  0.  0.  5.  0.]]
#                                     else:  # if Code > 23.5
#                                       return [[ 0.  0.  1.  0.  0.]]
#                                 else:  # if Cd/Cm+WS > 2.71000003815
#                                   return [[ 0.  3.  0.  0.  0.]]
#                             else:  # if AVG Len > 18.0
#                               return [[ 0.  0.  6.  0.  0.]]
#                           else:  # if Cd/WS > 3.44000005722
#                             if Code <= 27.5:
#                               if max_nesting_depth <= 2.5:
#                                 if McCabes_cyclomatic_complexity <= 3.5:
#                                   return [[  0.   0.   0.   0.  12.]]
#                                 else:  # if McCabes_cyclomatic_complexity > 3.5
#                                   return [[  0.   0.  10.   0.   0.]]
#                               else:  # if max_nesting_depth > 2.5
#                                 if % Code <= 0.814999997616:
#                                   if AVG Len <= 13.5:
#                                     if lines_of_code <= 21.5:
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                     else:  # if lines_of_code > 21.5
#                                       return [[ 1.  0.  0.  0.  0.]]
#                                   else:  # if AVG Len > 13.5
#                                     if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                       return [[ 0.  0.  0.  2.  0.]]
#                                     else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                       return [[  0.   0.   0.   0.  11.]]
#                                 else:  # if % Code > 0.814999997616
#                                   if Lines <= 28.5:
#                                     if max_params_in_decl <= 0.5:
#                                       if % Code <= 0.875:
#                                         if AVG Len <= 17.5:
#                                           if Lines <= 27.5:
#                                             if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                               return [[ 0.  2.  0.  0.  0.]]
#                                             else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                               if Comments <= 0.5:
#                                                 if max_nesting_depth <= 3.5:
#                                                   return [[ 0.  0.  0.  0.  7.]]
#                                                 else:  # if max_nesting_depth > 3.5
#                                                   return [[ 0.  1.  0.  0.  0.]]
#                                               else:  # if Comments > 0.5
#                                                 return [[ 0.  1.  0.  0.  0.]]
#                                           else:  # if Lines > 27.5
#                                             if lines_of_code_per_line_of_comment <= 11.0:
#                                               return [[ 0.  6.  0.  0.  0.]]
#                                             else:  # if lines_of_code_per_line_of_comment > 11.0
#                                               return [[ 0.  0.  0.  0.  1.]]
#                                         else:  # if AVG Len > 17.5
#                                           return [[ 0.  0.  0.  2.  0.]]
#                                       else:  # if % Code > 0.875
#                                         if McCabes_cyclomatic_complexity_per_module <= 4.0:
#                                           if AVG Len <= 17.5:
#                                             return [[ 1.  0.  0.  0.  0.]]
#                                           else:  # if AVG Len > 17.5
#                                             return [[ 0.  2.  0.  0.  0.]]
#                                         else:  # if McCabes_cyclomatic_complexity_per_module > 4.0
#                                           return [[ 0.  0.  0.  4.  0.]]
#                                     else:  # if max_params_in_decl > 0.5
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                   else:  # if Lines > 28.5
#                                     if Cd/WS <= 5.625:
#                                       return [[ 0.  0.  0.  6.  0.]]
#                                     else:  # if Cd/WS > 5.625
#                                       return [[ 0.  0.  0.  0.  2.]]
#                             else:  # if Code > 27.5
#                               if Code <= 39.5:
#                                 return [[ 0.  0.  0.  8.  0.]]
#                               else:  # if Code > 39.5
#                                 return [[ 0.  2.  0.  0.  0.]]
#                         else:  # if Cd/Cm+WS > 7.83500003815
#                           if Cd/Cm+WS <= 8.55000019073:
#                             return [[  0.   0.  10.   0.   0.]]
#                           else:  # if Cd/Cm+WS > 8.55000019073
#                             if lines_of_code_per_module <= 18.5:
#                               if McCabes_cyclomatic_complexity <= 2.5:
#                                 if lines_of_comment_per_module <= 0.5:
#                                   return [[ 0.  0.  6.  0.  0.]]
#                                 else:  # if lines_of_comment_per_module > 0.5
#                                   return [[ 0.  2.  0.  0.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity > 2.5
#                                 if Cd/Cm+WS <= 9.41499996185:
#                                   if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                     return [[ 0.  0.  2.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                     if McCabes_cyclomatic_complexity_per_module <= 5.0:
#                                       return [[ 0.  1.  0.  0.  0.]]
#                                     else:  # if McCabes_cyclomatic_complexity_per_module > 5.0
#                                       return [[ 1.  0.  0.  0.  0.]]
#                                 else:  # if Cd/Cm+WS > 9.41499996185
#                                   if Cd/WS <= 18.75:
#                                     return [[  0.  13.   0.   0.   0.]]
#                                   else:  # if Cd/WS > 18.75
#                                     return [[ 0.  0.  0.  0.  1.]]
#                             else:  # if lines_of_code_per_module > 18.5
#                               if AVG Len <= 15.5:
#                                 if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                   return [[ 0.  0.  2.  0.  0.]]
#                                 else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                   if Cd/WS <= 11.25:
#                                     return [[ 0.  0.  0.  0.  6.]]
#                                   else:  # if Cd/WS > 11.25
#                                     if McCabes_cyclomatic_complexity_per_module <= 4.5:
#                                       return [[ 0.  1.  0.  0.  0.]]
#                                     else:  # if McCabes_cyclomatic_complexity_per_module > 4.5
#                                       return [[ 0.  0.  0.  0.  2.]]
#                               else:  # if AVG Len > 15.5
#                                 if lines_of_code_per_module <= 21.5:
#                                   return [[ 0.  0.  6.  0.  0.]]
#                                 else:  # if lines_of_code_per_module > 21.5
#                                   if Code <= 25.0:
#                                     return [[ 0.  0.  0.  2.  0.]]
#                                   else:  # if Code > 25.0
#                                     return [[ 3.  0.  0.  0.  0.]]
#                     else:  # if Comments > 1.5
#                       if Cd/WS <= 11.25:
#                         if White SP <= 6.5:
#                           if Cd/WS <= 3.90000009537:
#                             return [[ 0.  1.  0.  0.  0.]]
#                           else:  # if Cd/WS > 3.90000009537
#                             if AVG Len <= 16.5:
#                               return [[  0.   0.   0.  14.   0.]]
#                             else:  # if AVG Len > 16.5
#                               if Code <= 23.5:
#                                 return [[ 0.  0.  0.  3.  0.]]
#                               else:  # if Code > 23.5
#                                 return [[ 0.  2.  0.  0.  0.]]
#                         else:  # if White SP > 6.5
#                           return [[ 0.  4.  0.  0.  0.]]
#                       else:  # if Cd/WS > 11.25
#                         if Cd/WS <= 22.0:
#                           return [[ 0.  0.  0.  0.  4.]]
#                         else:  # if Cd/WS > 22.0
#                           return [[ 0.  0.  1.  0.  0.]]
#                 else:  # if McCabes_cyclomatic_complexity > 6.5
#                   if Code <= 38.0:
#                     if lines_of_code_per_module <= 16.75:
#                       if Cd/Cm+WS <= 5.625:
#                         return [[ 0.  0.  0.  0.  1.]]
#                       else:  # if Cd/Cm+WS > 5.625
#                         return [[ 1.  0.  2.  0.  0.]]
#                     else:  # if lines_of_code_per_module > 16.75
#                       if Comments <= 1.5:
#                         if Lines <= 22.5:
#                           return [[ 2.  0.  0.  0.  0.]]
#                         else:  # if Lines > 22.5
#                           if max_nesting_depth <= 2.5:
#                             if number_of_modules <= 1.5:
#                               if AVG Len <= 17.0:
#                                 return [[ 0.  0.  1.  0.  0.]]
#                               else:  # if AVG Len > 17.0
#                                 return [[ 0.  0.  0.  0.  2.]]
#                             else:  # if number_of_modules > 1.5
#                               return [[ 0.  0.  0.  5.  0.]]
#                           else:  # if max_nesting_depth > 2.5
#                             if Code <= 25.0:
#                               return [[  0.   0.   0.  16.   0.]]
#                             else:  # if Code > 25.0
#                               return [[ 1.  0.  0.  0.  0.]]
#                       else:  # if Comments > 1.5
#                         return [[ 2.  0.  0.  0.  0.]]
#                   else:  # if Code > 38.0
#                     return [[ 0.  0.  4.  0.  0.]]
#               else:  # if lines_of_code > 40.5
#                 return [[  0.  10.   0.   0.   0.]]
#             else:  # if max_params_in_decl > 1.5
#               if Cd/Cm+WS <= 5.00500011444:
#                 if lines_of_code_per_module <= 19.5:
#                   if Cd/Cm <= 48.75:
#                     return [[  0.   0.  12.   0.   0.]]
#                   else:  # if Cd/Cm > 48.75
#                     if max_params_in_decl <= 2.5:
#                       return [[ 2.  0.  0.  0.  0.]]
#                     else:  # if max_params_in_decl > 2.5
#                       return [[ 0.  0.  0.  0.  2.]]
#                 else:  # if lines_of_code_per_module > 19.5
#                   if AVG Len <= 15.5:
#                     return [[ 0.  0.  0.  2.  0.]]
#                   else:  # if AVG Len > 15.5
#                     if lines_of_comment_per_module <= 1.0:
#                       return [[ 2.  0.  0.  0.  0.]]
#                     else:  # if lines_of_comment_per_module > 1.0
#                       return [[ 0.  1.  0.  0.  0.]]
#               else:  # if Cd/Cm+WS > 5.00500011444
#                 if McCabes_cyclomatic_complexity <= 1.0:
#                   if White SP <= 16.0:
#                     return [[ 0.  0.  4.  0.  0.]]
#                   else:  # if White SP > 16.0
#                     return [[ 0.  0.  0.  2.  0.]]
#                 else:  # if McCabes_cyclomatic_complexity > 1.0
#                   if AVG Len <= 21.0:
#                     if number_of_modules <= 4.5:
#                       if McCabes_cyclomatic_complexity_per_module <= 6.875:
#                         if McCabes_cyclomatic_complexity_per_module <= 4.5:
#                           return [[  0.   0.   0.   0.  32.]]
#                         else:  # if McCabes_cyclomatic_complexity_per_module > 4.5
#                           if McCabes_cyclomatic_complexity <= 5.5:
#                             return [[ 0.  0.  4.  0.  0.]]
#                           else:  # if McCabes_cyclomatic_complexity > 5.5
#                             return [[ 0.  0.  0.  0.  8.]]
#                       else:  # if McCabes_cyclomatic_complexity_per_module > 6.875
#                         return [[ 0.  2.  0.  0.  0.]]
#                     else:  # if number_of_modules > 4.5
#                       return [[ 0.  2.  0.  0.  0.]]
#                   else:  # if AVG Len > 21.0
#                     return [[ 3.  0.  0.  0.  0.]]
#           else:  # if lines_of_code_per_module > 22.75
#             if AVG Len <= 11.5:
#               if McCabes_cyclomatic_complexity <= 6.0:
#                 if Cd/WS <= 7.5:
#                   if lines_of_code <= 25.5:
#                     return [[ 0.  9.  0.  0.  0.]]
#                   else:  # if lines_of_code > 25.5
#                     if Comments <= 0.5:
#                       if Code <= 28.0:
#                         return [[ 0.  0.  0.  2.  0.]]
#                       else:  # if Code > 28.0
#                         return [[ 0.  0.  0.  0.  2.]]
#                     else:  # if Comments > 0.5
#                       return [[ 0.  5.  0.  0.  0.]]
#                 else:  # if Cd/WS > 7.5
#                   if McCabes_cyclomatic_complexity <= 3.5:
#                     return [[ 0.  0.  0.  4.  0.]]
#                   else:  # if McCabes_cyclomatic_complexity > 3.5
#                     return [[ 0.  0.  0.  0.  4.]]
#               else:  # if McCabes_cyclomatic_complexity > 6.0
#                 return [[ 0.  0.  0.  7.  0.]]
#             else:  # if AVG Len > 11.5
#               if AVG Len <= 13.5:
#                 if White SP <= 16.5:
#                   if Lines <= 33.0:
#                     if rejected_lines_of_code
#  <= 0.5:
#                       return [[ 0.  0.  9.  0.  0.]]
#                     else:  # if rejected_lines_of_code
#  > 0.5
#                       return [[ 0.  0.  0.  0.  4.]]
#                   else:  # if Lines > 33.0
#                     if lines_of_code_per_module <= 26.5:
#                       return [[  0.   0.  21.   0.   0.]]
#                     else:  # if lines_of_code_per_module > 26.5
#                       if max_nesting_depth <= 3.5:
#                         return [[ 0.  0.  4.  0.  0.]]
#                       else:  # if max_nesting_depth > 3.5
#                         return [[ 0.  1.  0.  0.  0.]]
#                 else:  # if White SP > 16.5
#                   return [[ 0.  2.  0.  0.  0.]]
#               else:  # if AVG Len > 13.5
#                 if Cd/Cm+WS <= 2.95499992371:
#                   if % Code <= 0.649999976158:
#                     return [[ 1.  0.  0.  0.  0.]]
#                   else:  # if % Code > 0.649999976158
#                     if max_nested_loops <= 2.5:
#                       return [[  0.   0.   0.  12.   0.]]
#                     else:  # if max_nested_loops > 2.5
#                       return [[ 0.  1.  0.  0.  0.]]
#                 else:  # if Cd/Cm+WS > 2.95499992371
#                   if AVG Len <= 18.5:
#                     if Code <= 43.5:
#                       if lines_of_code <= 24.5:
#                         if AVG Len <= 16.5:
#                           if McCabes_cyclomatic_complexity <= 3.5:
#                             return [[ 0.  4.  0.  0.  0.]]
#                           else:  # if McCabes_cyclomatic_complexity > 3.5
#                             if Cd/WS <= 8.125:
#                               if White SP <= 7.5:
#                                 if max_nested_loops <= 2.5:
#                                   if AVG Len <= 14.5:
#                                     if Cd/WS <= 4.54500007629:
#                                       return [[ 0.  0.  0.  4.  0.]]
#                                     else:  # if Cd/WS > 4.54500007629
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                   else:  # if AVG Len > 14.5
#                                     return [[  0.   0.   0.  14.   0.]]
#                                 else:  # if max_nested_loops > 2.5
#                                   return [[ 0.  0.  2.  0.  0.]]
#                               else:  # if White SP > 7.5
#                                 return [[ 0.  0.  2.  0.  0.]]
#                             else:  # if Cd/WS > 8.125
#                               if rejected_lines_of_code
#  <= 0.5:
#                                 return [[ 0.  6.  0.  0.  0.]]
#                               else:  # if rejected_lines_of_code
#  > 0.5
#                                 if McCabes_cyclomatic_complexity_per_module <= 4.5:
#                                   return [[ 0.  0.  0.  4.  0.]]
#                                 else:  # if McCabes_cyclomatic_complexity_per_module > 4.5
#                                   if Cd/WS <= 11.3350000381:
#                                     if Lines <= 31.5:
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                     else:  # if Lines > 31.5
#                                       return [[ 2.  0.  0.  0.  0.]]
#                                   else:  # if Cd/WS > 11.3350000381
#                                     return [[ 0.  0.  0.  0.  2.]]
#                         else:  # if AVG Len > 16.5
#                           if Cd/Cm+WS <= 8.33500003815:
#                             if % Code <= 0.840000033379:
#                               return [[ 0.  0.  6.  0.  0.]]
#                             else:  # if % Code > 0.840000033379
#                               if max_nested_loops <= 2.5:
#                                 return [[ 0.  0.  3.  0.  0.]]
#                               else:  # if max_nested_loops > 2.5
#                                 return [[ 1.  0.  0.  0.  0.]]
#                           else:  # if Cd/Cm+WS > 8.33500003815
#                             if lines_of_code <= 23.5:
#                               return [[ 3.  0.  0.  0.  0.]]
#                             else:  # if lines_of_code > 23.5
#                               return [[ 0.  4.  0.  0.  0.]]
#                       else:  # if lines_of_code > 24.5
#                         if Cd/Cm <= 18.5:
#                           if max_nested_loops <= 1.5:
#                             if White SP <= 6.5:
#                               if Cd/WS <= 13.75:
#                                 return [[ 0.  8.  0.  0.  0.]]
#                               else:  # if Cd/WS > 13.75
#                                 return [[ 2.  0.  0.  0.  0.]]
#                             else:  # if White SP > 6.5
#                               return [[ 0.  0.  2.  0.  0.]]
#                           else:  # if max_nested_loops > 1.5
#                             if White SP <= 8.5:
#                               if Cd/WS <= 6.55000019073:
#                                 if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                   if McCabes_cyclomatic_complexity_per_module <= 2.5:
#                                     return [[ 0.  0.  2.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity_per_module > 2.5
#                                     return [[ 1.  0.  0.  0.  0.]]
#                                 else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                   return [[  0.   0.  16.   0.   0.]]
#                               else:  # if Cd/WS > 6.55000019073
#                                 if % Code <= 0.894999980927:
#                                   if McCabes_cyclomatic_complexity_per_module <= 4.5:
#                                     if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                       return [[ 1.  0.  0.  0.  0.]]
#                                     else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity_per_module > 4.5
#                                     return [[ 0.  0.  0.  0.  3.]]
#                                 else:  # if % Code > 0.894999980927
#                                   if McCabes_cyclomatic_complexity <= 5.5:
#                                     if AVG Len <= 17.5:
#                                       return [[  0.   0.  14.   0.   0.]]
#                                     else:  # if AVG Len > 17.5
#                                       return [[ 2.  0.  0.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity > 5.5
#                                     if White SP <= 2.5:
#                                       return [[ 0.  4.  0.  0.  0.]]
#                                     else:  # if White SP > 2.5
#                                       return [[ 0.  0.  2.  0.  0.]]
#                             else:  # if White SP > 8.5
#                               return [[ 0.  4.  0.  0.  0.]]
#                         else:  # if Cd/Cm > 18.5
#                           if Code <= 27.5:
#                             return [[ 0.  0.  0.  2.  0.]]
#                           else:  # if Code > 27.5
#                             return [[ 0.  6.  0.  0.  0.]]
#                     else:  # if Code > 43.5
#                       return [[  0.   0.  12.   0.   0.]]
#                   else:  # if AVG Len > 18.5
#                     if max_nesting_depth <= 3.5:
#                       if Cd/WS <= 14.75:
#                         if Cd/Cm <= 29.0:
#                           if McCabes_cyclomatic_complexity_per_line_of_comment <= 3.25:
#                             if % Code <= 0.794999957085:
#                               if Lines <= 37.5:
#                                 return [[ 0.  0.  0.  4.  0.]]
#                               else:  # if Lines > 37.5
#                                 return [[ 2.  0.  0.  0.  0.]]
#                             else:  # if % Code > 0.794999957085
#                               if AVG Len <= 19.5:
#                                 return [[  0.   0.  10.   0.   0.]]
#                               else:  # if AVG Len > 19.5
#                                 if % Code <= 0.894999980927:
#                                   if max_params_in_decl <= 0.5:
#                                     if Code <= 28.0:
#                                       if rejected_lines_of_code
#  <= 0.5:
#                                         return [[ 0.  0.  3.  0.  0.]]
#                                       else:  # if rejected_lines_of_code
#  > 0.5
#                                         return [[ 0.  0.  0.  2.  0.]]
#                                     else:  # if Code > 28.0
#                                       return [[ 0.  0.  4.  0.  0.]]
#                                   else:  # if max_params_in_decl > 0.5
#                                     if Lines <= 33.5:
#                                       return [[ 0.  0.  0.  2.  0.]]
#                                     else:  # if Lines > 33.5
#                                       return [[ 0.  1.  0.  0.  0.]]
#                                 else:  # if % Code > 0.894999980927
#                                   if lines_of_code_per_module <= 25.8999996185:
#                                     if lines_of_code_per_module <= 23.5:
#                                       return [[ 0.  3.  0.  0.  0.]]
#                                     else:  # if lines_of_code_per_module > 23.5
#                                       if McCabes_cyclomatic_complexity <= 5.5:
#                                         return [[ 0.  1.  0.  0.  0.]]
#                                       else:  # if McCabes_cyclomatic_complexity > 5.5
#                                         return [[ 0.  0.  4.  0.  0.]]
#                                   else:  # if lines_of_code_per_module > 25.8999996185
#                                     if lines_of_code_per_module <= 26.5:
#                                       return [[ 0.  0.  0.  0.  6.]]
#                                     else:  # if lines_of_code_per_module > 26.5
#                                       return [[ 0.  1.  0.  0.  0.]]
#                           else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 3.25
#                             return [[ 0.  0.  0.  6.  0.]]
#                         else:  # if Cd/Cm > 29.0
#                           return [[  0.   0.  10.   0.   0.]]
#                       else:  # if Cd/WS > 14.75
#                         if AVG Len <= 19.5:
#                           return [[ 0.  0.  0.  0.  4.]]
#                         else:  # if AVG Len > 19.5
#                           return [[ 2.  0.  0.  0.  0.]]
#                     else:  # if max_nesting_depth > 3.5
#                       if member_funs <= 4.5:
#                         if % Code <= 0.794999957085:
#                           return [[ 0.  0.  2.  0.  0.]]
#                         else:  # if % Code > 0.794999957085
#                           if % Code <= 0.860000014305:
#                             if Lines <= 31.5:
#                               return [[ 0.  0.  0.  0.  4.]]
#                             else:  # if Lines > 31.5
#                               return [[ 0.  0.  2.  0.  0.]]
#                           else:  # if % Code > 0.860000014305
#                             return [[  0.   0.   0.   0.  10.]]
#                       else:  # if member_funs > 4.5
#                         return [[ 0.  2.  0.  0.  0.]]
#         else:  # if lines_of_code_per_module > 27.75
#           if White SP <= 56.5:
#             if McCabes_cyclomatic_complexity_per_module <= 36.5:
#               if Cd/WS <= 19.125:
#                 if Cd/Cm+WS <= 16.5849990845:
#                   if Cd/Cm+WS <= 4.79500007629:
#                     if Code <= 48.5:
#                       if max_params_in_decl <= 2.5:
#                         if Lines <= 54.5:
#                           if White SP <= 12.5:
#                             if Lines <= 51.5:
#                               if lines_of_code <= 36.5:
#                                 if Cd/WS <= 4.46500015259:
#                                   if AVG Len <= 15.5:
#                                     if max_nested_loops <= 2.5:
#                                       if McCabes_cyclomatic_complexity <= 5.5:
#                                         if lines_of_code_per_module <= 31.5:
#                                           if lines_of_code_per_module <= 28.5:
#                                             return [[ 0.  0.  0.  2.  0.]]
#                                           else:  # if lines_of_code_per_module > 28.5
#                                             return [[ 0.  0.  0.  0.  6.]]
#                                         else:  # if lines_of_code_per_module > 31.5
#                                           if McCabes_cyclomatic_complexity <= 4.0:
#                                             return [[ 0.  0.  2.  0.  0.]]
#                                           else:  # if McCabes_cyclomatic_complexity > 4.0
#                                             return [[ 1.  0.  0.  0.  0.]]
#                                       else:  # if McCabes_cyclomatic_complexity > 5.5
#                                         if White SP <= 10.5:
#                                           return [[  0.   0.   0.  18.   0.]]
#                                         else:  # if White SP > 10.5
#                                           if AVG Len <= 14.5:
#                                             return [[ 3.  0.  0.  0.  0.]]
#                                           else:  # if AVG Len > 14.5
#                                             return [[ 0.  0.  1.  0.  0.]]
#                                     else:  # if max_nested_loops > 2.5
#                                       if Code <= 35.5:
#                                         if % Code <= 0.77999997139:
#                                           if Cd/WS <= 3.13999986649:
#                                             return [[ 0.  1.  0.  0.  0.]]
#                                           else:  # if Cd/WS > 3.13999986649
#                                             return [[ 0.  0.  0.  1.  0.]]
#                                         else:  # if % Code > 0.77999997139
#                                           return [[ 0.  0.  3.  0.  0.]]
#                                       else:  # if Code > 35.5
#                                         return [[ 0.  0.  0.  0.  8.]]
#                                   else:  # if AVG Len > 15.5
#                                     if AVG Len <= 19.5:
#                                       if rejected_lines_of_code
#  <= 0.5:
#                                         return [[ 0.  0.  0.  0.  4.]]
#                                       else:  # if rejected_lines_of_code
#  > 0.5
#                                         if lines_of_code <= 28.5:
#                                           if lines_of_comment_per_module <= 1.0:
#                                             return [[ 0.  0.  0.  1.  0.]]
#                                           else:  # if lines_of_comment_per_module > 1.0
#                                             return [[ 0.  0.  2.  0.  0.]]
#                                         else:  # if lines_of_code > 28.5
#                                           if Lines <= 49.5:
#                                             return [[  0.  13.   0.   0.   0.]]
#                                           else:  # if Lines > 49.5
#                                             return [[ 2.  0.  0.  0.  0.]]
#                                     else:  # if AVG Len > 19.5
#                                       if McCabes_cyclomatic_complexity_per_module <= 9.5:
#                                         return [[ 0.  0.  1.  0.  0.]]
#                                       else:  # if McCabes_cyclomatic_complexity_per_module > 9.5
#                                         if lines_of_code <= 35.5:
#                                           return [[ 0.  0.  0.  8.  0.]]
#                                         else:  # if lines_of_code > 35.5
#                                           return [[ 0.  1.  0.  0.  0.]]
#                                 else:  # if Cd/WS > 4.46500015259
#                                   if lines_of_code <= 30.5:
#                                     if Lines <= 38.5:
#                                       return [[ 1.  0.  0.  0.  0.]]
#                                     else:  # if Lines > 38.5
#                                       return [[  0.  12.   0.   0.   0.]]
#                                   else:  # if lines_of_code > 30.5
#                                     if Cd/WS <= 5.75:
#                                       if McCabes_cyclomatic_complexity <= 8.5:
#                                         if rejected_lines_of_code
#  <= 0.5:
#                                           if lines_of_code_per_line_of_comment <= 18.0:
#                                             return [[ 0.  1.  0.  0.  0.]]
#                                           else:  # if lines_of_code_per_line_of_comment > 18.0
#                                             return [[ 0.  0.  1.  0.  0.]]
#                                         else:  # if rejected_lines_of_code
#  > 0.5
#                                           return [[ 3.  0.  0.  0.  0.]]
#                                       else:  # if McCabes_cyclomatic_complexity > 8.5
#                                         if Code <= 36.0:
#                                           return [[ 0.  0.  0.  6.  0.]]
#                                         else:  # if Code > 36.0
#                                           return [[ 0.  0.  0.  0.  1.]]
#                                     else:  # if Cd/WS > 5.75
#                                       return [[ 0.  6.  0.  0.  0.]]
#                               else:  # if lines_of_code > 36.5
#                                 if McCabes_cyclomatic_complexity <= 15.5:
#                                   if lines_of_code_per_line_of_comment <= 37.5:
#                                     return [[  0.  13.   0.   0.   0.]]
#                                   else:  # if lines_of_code_per_line_of_comment > 37.5
#                                     return [[ 0.  0.  2.  0.  0.]]
#                                 else:  # if McCabes_cyclomatic_complexity > 15.5
#                                   return [[ 0.  0.  0.  0.  4.]]
#                             else:  # if Lines > 51.5
#                               if max_nesting_depth <= 2.5:
#                                 return [[ 0.  3.  0.  0.  0.]]
#                               else:  # if max_nesting_depth > 2.5
#                                 if max_nested_loops <= 3.5:
#                                   if McCabes_cyclomatic_complexity <= 14.5:
#                                     if lines_of_code_per_module <= 31.5:
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                     else:  # if lines_of_code_per_module > 31.5
#                                       if McCabes_cyclomatic_complexity_per_module <= 12.5:
#                                         return [[  0.   0.   0.  19.   0.]]
#                                       else:  # if McCabes_cyclomatic_complexity_per_module > 12.5
#                                         if McCabes_cyclomatic_complexity <= 13.5:
#                                           return [[ 0.  0.  1.  0.  0.]]
#                                         else:  # if McCabes_cyclomatic_complexity > 13.5
#                                           return [[ 0.  0.  0.  2.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity > 14.5
#                                     return [[ 0.  2.  0.  0.  0.]]
#                                 else:  # if max_nested_loops > 3.5
#                                   return [[ 0.  0.  0.  0.  2.]]
#                           else:  # if White SP > 12.5
#                             if Lines <= 50.5:
#                               return [[ 0.  0.  4.  0.  0.]]
#                             else:  # if Lines > 50.5
#                               if AVG Len <= 15.5:
#                                 return [[ 0.  0.  0.  0.  8.]]
#                               else:  # if AVG Len > 15.5
#                                 if lines_of_code_per_module <= 33.5:
#                                   if McCabes_cyclomatic_complexity_per_line_of_comment <= 3.5:
#                                     return [[ 0.  0.  2.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 3.5
#                                     if Cd/Cm <= 28.0:
#                                       return [[ 0.  0.  0.  0.  2.]]
#                                     else:  # if Cd/Cm > 28.0
#                                       return [[ 0.  0.  0.  1.  0.]]
#                                 else:  # if lines_of_code_per_module > 33.5
#                                   return [[ 0.  3.  0.  0.  0.]]
#                         else:  # if Lines > 54.5
#                           if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                             return [[ 0.  0.  0.  5.  0.]]
#                           else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                             if AVG Len <= 17.5:
#                               if McCabes_cyclomatic_complexity_per_line_of_comment <= 1.25:
#                                 if max_nesting_depth <= 2.5:
#                                   return [[ 0.  6.  0.  0.  0.]]
#                                 else:  # if max_nesting_depth > 2.5
#                                   if McCabes_cyclomatic_complexity_per_module <= 13.5:
#                                     if Cd/WS <= 2.48500013351:
#                                       if McCabes_cyclomatic_complexity_per_module <= 9.0:
#                                         return [[ 1.  0.  0.  0.  0.]]
#                                       else:  # if McCabes_cyclomatic_complexity_per_module > 9.0
#                                         return [[ 0.  0.  0.  3.  0.]]
#                                     else:  # if Cd/WS > 2.48500013351
#                                       if max_nested_loops <= 2.5:
#                                         if % Code <= 0.805000007153:
#                                           if AVG Len <= 15.0:
#                                             if Lines <= 55.5:
#                                               return [[ 0.  1.  0.  0.  0.]]
#                                             else:  # if Lines > 55.5
#                                               return [[ 0.  0.  0.  0.  3.]]
#                                           else:  # if AVG Len > 15.0
#                                             return [[ 0.  0.  0.  1.  0.]]
#                                         else:  # if % Code > 0.805000007153
#                                           return [[ 0.  3.  0.  0.  0.]]
#                                       else:  # if max_nested_loops > 2.5
#                                         return [[ 0.  0.  0.  0.  6.]]
#                                   else:  # if McCabes_cyclomatic_complexity_per_module > 13.5
#                                     return [[ 3.  0.  0.  0.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 1.25
#                                 if max_nesting_depth <= 3.5:
#                                   if max_params_in_decl <= 1.5:
#                                     return [[ 0.  0.  7.  0.  0.]]
#                                   else:  # if max_params_in_decl > 1.5
#                                     if Cd/Cm+WS <= 3.81999993324:
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                     else:  # if Cd/Cm+WS > 3.81999993324
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                 else:  # if max_nesting_depth > 3.5
#                                   if Cd/Cm+WS <= 3.87999987602:
#                                     if McCabes_cyclomatic_complexity_per_module <= 10.0:
#                                       if lines_of_code_per_line_of_comment <= 19.75:
#                                         return [[ 0.  0.  2.  0.  0.]]
#                                       else:  # if lines_of_code_per_line_of_comment > 19.75
#                                         return [[ 0.  3.  0.  0.  0.]]
#                                     else:  # if McCabes_cyclomatic_complexity_per_module > 10.0
#                                       return [[ 3.  0.  0.  0.  0.]]
#                                   else:  # if Cd/Cm+WS > 3.87999987602
#                                     return [[ 0.  0.  0.  0.  3.]]
#                             else:  # if AVG Len > 17.5
#                               if Cd/Cm+WS <= 4.09000015259:
#                                 if lines_of_code_per_module <= 35.5:
#                                   return [[ 8.  0.  0.  0.  0.]]
#                                 else:  # if lines_of_code_per_module > 35.5
#                                   if Code <= 45.0:
#                                     if max_nesting_depth <= 4.5:
#                                       return [[  0.   0.  10.   0.   0.]]
#                                     else:  # if max_nesting_depth > 4.5
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                   else:  # if Code > 45.0
# ...
#  > 8.5
#                           if Cd/Cm+WS <= 8.53499984741:
#                             return [[  0.   0.   0.  10.   0.]]
#                           else:  # if Cd/Cm+WS > 8.53499984741
#                             if Lines <= 139.0:
#                               if Cd/Cm+WS <= 16.2649993896:
#                                 if lines_of_comment_per_module <= 2.0:
#                                   return [[ 0.  0.  0.  2.  0.]]
#                                 else:  # if lines_of_comment_per_module > 2.0
#                                   return [[ 0.  0.  0.  0.  1.]]
#                               else:  # if Cd/Cm+WS > 16.2649993896
#                                 return [[ 0.  0.  2.  0.  0.]]
#                             else:  # if Lines > 139.0
#                               return [[ 0.  9.  0.  0.  0.]]
#                     else:  # if max_params_in_decl > 1.5
#                       if lines_of_code_per_module <= 81.0:
#                         if lines_of_code_per_module <= 41.1665000916:
#                           if lines_of_code <= 109.5:
#                             return [[ 0.  0.  0.  0.  2.]]
#                           else:  # if lines_of_code > 109.5
#                             return [[  0.   0.  10.   0.   0.]]
#                         else:  # if lines_of_code_per_module > 41.1665000916
#                           if McCabes_cyclomatic_complexity <= 25.5:
#                             if Code <= 114.0:
#                               return [[ 0.  0.  2.  0.  0.]]
#                             else:  # if Code > 114.0
#                               return [[ 5.  0.  0.  0.  0.]]
#                           else:  # if McCabes_cyclomatic_complexity > 25.5
#                             if McCabes_cyclomatic_complexity_per_line_of_comment <= 6.41650009155:
#                               if McCabes_cyclomatic_complexity_per_module <= 9.83349990845:
#                                 return [[ 0.  0.  0.  4.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity_per_module > 9.83349990845
#                                 return [[ 0.  0.  6.  0.  0.]]
#                             else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 6.41650009155
#                               if AVG Len <= 14.5:
#                                 if lines_of_comment_per_module <= 1.5:
#                                   return [[ 0.  0.  2.  0.  0.]]
#                                 else:  # if lines_of_comment_per_module > 1.5
#                                   return [[ 0.  2.  0.  0.  0.]]
#                               else:  # if AVG Len > 14.5
#                                 if McCabes_cyclomatic_complexity <= 43.0:
#                                   return [[  0.   0.   0.  21.   0.]]
#                                 else:  # if McCabes_cyclomatic_complexity > 43.0
#                                   if Code <= 214.5:
#                                     if Code <= 183.5:
#                                       if lines_of_code_per_module <= 55.9165000916:
#                                         return [[ 0.  0.  0.  1.  0.]]
#                                       else:  # if lines_of_code_per_module > 55.9165000916
#                                         return [[ 0.  1.  0.  0.  0.]]
#                                     else:  # if Code > 183.5
#                                       return [[ 0.  0.  0.  0.  3.]]
#                                   else:  # if Code > 214.5
#                                     return [[ 0.  0.  0.  7.  0.]]
#                       else:  # if lines_of_code_per_module > 81.0
#                         if McCabes_cyclomatic_complexity_per_line_of_comment <= 16.75:
#                           if McCabes_cyclomatic_complexity_per_module <= 33.5:
#                             if Lines <= 171.5:
#                               if Lines <= 162.0:
#                                 if Cd/Cm <= 19.5799999237:
#                                   return [[ 0.  0.  0.  6.  0.]]
#                                 else:  # if Cd/Cm > 19.5799999237
#                                   if Cd/Cm <= 41.6650009155:
#                                     if Code <= 118.0:
#                                       return [[  0.  13.   0.   0.   0.]]
#                                     else:  # if Code > 118.0
#                                       if lines_of_code_per_line_of_comment <= 27.3665008545:
#                                         if AVG Len <= 21.0:
#                                           if AVG Len <= 19.5:
#                                             return [[ 0.  0.  8.  0.  0.]]
#                                           else:  # if AVG Len > 19.5
#                                             if lines_of_code_per_module <= 106.0:
#                                               return [[ 0.  0.  1.  0.  0.]]
#                                             else:  # if lines_of_code_per_module > 106.0
#                                               return [[ 0.  2.  0.  0.  0.]]
#                                         else:  # if AVG Len > 21.0
#                                           if Cd/Cm+WS <= 9.06500053406:
#                                             return [[ 0.  0.  0.  0.  5.]]
#                                           else:  # if Cd/Cm+WS > 9.06500053406
#                                             return [[ 0.  0.  2.  0.  0.]]
#                                       else:  # if lines_of_code_per_line_of_comment > 27.3665008545
#                                         return [[ 0.  6.  0.  0.  0.]]
#                                   else:  # if Cd/Cm > 41.6650009155
#                                     if AVG Len <= 23.0:
#                                       if Lines <= 148.0:
#                                         if Lines <= 128.5:
#                                           if lines_of_code_per_module <= 85.5:
#                                             return [[ 0.  0.  1.  0.  0.]]
#                                           else:  # if lines_of_code_per_module > 85.5
#                                             return [[ 0.  0.  0.  0.  4.]]
#                                         else:  # if Lines > 128.5
#                                           if lines_of_code_per_line_of_comment <= 52.0:
#                                             return [[ 0.  6.  0.  0.  0.]]
#                                           else:  # if lines_of_code_per_line_of_comment > 52.0
#                                             if Code <= 118.5:
#                                               if Lines <= 144.0:
#                                                 return [[ 7.  0.  0.  0.  0.]]
#                                               else:  # if Lines > 144.0
#                                                 return [[ 0.  2.  0.  0.  0.]]
#                                             else:  # if Code > 118.5
#                                               if lines_of_code_per_line_of_comment <= 56.0:
#                                                 return [[ 0.  0.  2.  0.  0.]]
#                                               else:  # if lines_of_code_per_line_of_comment > 56.0
#                                                 return [[ 0.  0.  0.  2.  0.]]
#                                       else:  # if Lines > 148.0
#                                         if Cd/Cm <= 46.6650009155:
#                                           if AVG Len <= 19.0:
#                                             return [[ 2.  0.  0.  0.  0.]]
#                                           else:  # if AVG Len > 19.0
#                                             return [[ 0.  0.  2.  0.  0.]]
#                                         else:  # if Cd/Cm > 46.6650009155
#                                           if lines_of_code_per_module <= 92.0:
#                                             return [[ 0.  1.  0.  0.  0.]]
#                                           else:  # if lines_of_code_per_module > 92.0
#                                             if Cd/Cm <= 64.75:
#                                               return [[  0.   0.   0.   0.  12.]]
#                                             else:  # if Cd/Cm > 64.75
#                                               return [[ 0.  0.  0.  1.  0.]]
#                                     else:  # if AVG Len > 23.0
#                                       return [[ 0.  0.  0.  6.  0.]]
#                               else:  # if Lines > 162.0
#                                 if Cd/Cm+WS <= 3.86000013351:
#                                   return [[ 0.  0.  8.  0.  0.]]
#                                 else:  # if Cd/Cm+WS > 3.86000013351
#                                   return [[  0.   0.   0.  13.   0.]]
#                             else:  # if Lines > 171.5
#                               if White SP <= 63.5:
#                                 if lines_of_code <= 114.5:
#                                   return [[ 0.  0.  2.  0.  0.]]
#                                 else:  # if lines_of_code > 114.5
#                                   return [[  0.  20.   0.   0.   0.]]
#                               else:  # if White SP > 63.5
#                                 if McCabes_cyclomatic_complexity_per_module <= 20.2145004272:
#                                   return [[ 1.  0.  0.  0.  0.]]
#                                 else:  # if McCabes_cyclomatic_complexity_per_module > 20.2145004272
#                                   if McCabes_cyclomatic_complexity <= 83.0:
#                                     return [[ 0.  0.  1.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity > 83.0
#                                     return [[ 2.  5.  3.  4.  0.]]
#                           else:  # if McCabes_cyclomatic_complexity_per_module > 33.5
#                             if McCabes_cyclomatic_complexity_per_line_of_comment <= 12.9169998169:
#                               if McCabes_cyclomatic_complexity_per_line_of_comment <= 10.0:
#                                 if McCabes_cyclomatic_complexity <= 53.0:
#                                   if McCabes_cyclomatic_complexity_per_line_of_comment <= 6.66249990463:
#                                     if % Code <= 0.799999952316:
#                                       return [[ 0.  0.  0.  0.  7.]]
#                                     else:  # if % Code > 0.799999952316
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 6.66249990463
#                                     if Cd/WS <= 14.75:
#                                       if McCabes_cyclomatic_complexity_per_module <= 48.5:
#                                         return [[  0.   0.   0.  16.   0.]]
#                                       else:  # if McCabes_cyclomatic_complexity_per_module > 48.5
#                                         return [[ 0.  0.  2.  0.  0.]]
#                                     else:  # if Cd/WS > 14.75
#                                       if lines_of_comment_per_module <= 5.0:
#                                         return [[ 0.  0.  0.  0.  4.]]
#                                       else:  # if lines_of_comment_per_module > 5.0
#                                         return [[ 0.  4.  0.  0.  0.]]
#                                 else:  # if McCabes_cyclomatic_complexity > 53.0
#                                   return [[ 6.  0.  0.  0.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 10.0
#                                 if lines_of_code <= 126.5:
#                                   if White SP <= 31.5:
#                                     return [[ 0.  0.  0.  1.  0.]]
#                                   else:  # if White SP > 31.5
#                                     return [[ 0.  0.  1.  0.  0.]]
#                                 else:  # if lines_of_code > 126.5
#                                   return [[  0.   0.   0.   0.  18.]]
#                             else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 12.9169998169
#                               if Code <= 127.5:
#                                 if % Code <= 0.949999988079:
#                                   return [[ 0.  0.  0.  2.  0.]]
#                                 else:  # if % Code > 0.949999988079
#                                   return [[ 0.  0.  1.  0.  0.]]
#                               else:  # if Code > 127.5
#                                 if Cd/Cm <= 55.3349990845:
#                                   if rejected_lines_of_code
#  <= 4.5:
#                                     return [[ 0.  0.  1.  0.  0.]]
#                                   else:  # if rejected_lines_of_code
#  > 4.5
#                                     return [[  0.  11.   0.   0.   0.]]
#                                 else:  # if Cd/Cm > 55.3349990845
#                                   return [[ 1.  0.  0.  0.  0.]]
#                         else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 16.75
#                           if White SP <= 13.5:
#                             if McCabes_cyclomatic_complexity <= 30.0:
#                               return [[ 3.  0.  0.  0.  0.]]
#                             else:  # if McCabes_cyclomatic_complexity > 30.0
#                               if AVG Len <= 21.0:
#                                 return [[ 0.  8.  0.  0.  0.]]
#                               else:  # if AVG Len > 21.0
#                                 return [[ 0.  0.  0.  2.  0.]]
#                           else:  # if White SP > 13.5
#                             if McCabes_cyclomatic_complexity_per_module <= 35.5:
#                               if McCabes_cyclomatic_complexity_per_line_of_comment <= 28.0:
#                                 if rejected_lines_of_code
#  <= 7.0:
#                                   return [[ 0.  0.  0.  5.  0.]]
#                                 else:  # if rejected_lines_of_code
#  > 7.0
#                                   if max_nested_loops <= 1.5:
#                                     return [[ 0.  0.  5.  0.  0.]]
#                                   else:  # if max_nested_loops > 1.5
#                                     return [[ 0.  3.  0.  0.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 28.0
#                                 if Lines <= 321.5:
#                                   return [[ 0.  0.  0.  0.  6.]]
#                                 else:  # if Lines > 321.5
#                                   return [[ 0.  0.  0.  1.  0.]]
#                             else:  # if McCabes_cyclomatic_complexity_per_module > 35.5
#                               if max_params_in_decl <= 3.5:
#                                 if AVG Len <= 15.0:
#                                   if McCabes_cyclomatic_complexity_per_module <= 44.5:
#                                     return [[ 0.  0.  1.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity_per_module > 44.5
#                                     return [[ 0.  0.  0.  2.  0.]]
#                                 else:  # if AVG Len > 15.0
#                                   if Cd/WS <= 5.74499988556:
#                                     return [[ 1.  0.  0.  0.  0.]]
#                                   else:  # if Cd/WS > 5.74499988556
#                                     return [[  0.   0.  25.   0.   0.]]
#                               else:  # if max_params_in_decl > 3.5
#                                 return [[ 0.  2.  0.  0.  0.]]
#                 else:  # if lines_of_code_per_module > 196.0
#                   if lines_of_code_per_line_of_comment <= 85.6665039062:
#                     return [[  0.   0.   0.   0.  10.]]
#                   else:  # if lines_of_code_per_line_of_comment > 85.6665039062
#                     return [[ 2.  0.  0.  0.  0.]]
#           else:  # if Cd/Cm > 196.5
#             if max_params_in_decl <= 4.5:
#               return [[  0.  14.   0.   0.   0.]]
#             else:  # if max_params_in_decl > 4.5
#               return [[ 2.  0.  0.  0.  0.]]

# %%
from sklearn import preprocessing
from sklearn.svm import SVC

X_train = preprocessing.scale(X_train) 
X_test = preprocessing.scale(X_test)

print ("Starting grid search...")

kernels = ['linear', 'rbf']
Cs = [1, 10, 100, 1000]

"""
for kernel in kernels:
    for C in Cs:
        print ("SVC:\t", kernel, " kernel\t| ", C, " C\t", end="\t")
        svc = SVC(C=C, kernel=kernel)
        svc.fit(X_train, y_train)
        print ("Score: ", svc.score(X_test, y_test))
        print ("\n")
"""
# Out:
# Starting grid search...
# '\nfor kernel in kernels:\n    for C in Cs:\n        print ("SVC:\t", kernel, " kernel\t| ", C, " C\t", end="\t")\n        svc = SVC(C=C, kernel=kernel)\n        svc.fit(X_train, y_train)\n        print ("Score: ", svc.score(X_test, y_test))\n        print ("\n")\n'
