# %%
import json
import numpy as np
import sys

def printf(format, *args):
    sys.stdout.write(format % args)
    
def load_json():
    
    authors = []
    features = []
    scores = []
    
    with open('dataset.json') as data_file:
        data = json.load(data_file)
        labels = data["column_descriptors"]
        author_data = data["author_data"]
        
        for author in author_data.keys():
            authors.append(author)
            features.append(author_data[author]['feature_vecs'])
            scores_str = author_data[author]['scores']
            scores.append(np.asarray([int(score_) for score_ in scores_str]))
    
    features = [np.asarray(feature) for feature in features]
    
    return labels, authors, features, scores

# %%
labels, authors, features, scores = load_json()
print (authors[0], features[0].shape, scores[0].shape, "\n")
print (labels)
# Out:
# yamauchi (7, 34) (7,)
#
# ['number_of_modules', 'lines_of_code', 'lines_of_code_per_module', 'McCabes_cyclomatic_complexity', 'McCabes_cyclomatic_complexity_per_module', 'lines_of_comment', 'lines_of_comment_per_module', 'lines_of_code_per_line_of_comment', 'McCabes_cyclomatic_complexity_per_line_of_comment', 'IF4', 'IF4_per_module', 'IF4_visible', 'IF4_visible_per_module', 'IF4_concrete', 'IF4_concrete', 'rejected_lines_of_code\n', 'Files', 'Lines', 'AVG Len', 'Code', 'Comments', 'White SP', 'Cd/Cm+WS', 'Cd/Cm', 'Cd/WS', '% Code', 'cnt_classes', 'max_member_funs', 'max_nested_loops', 'max_nesting_depth', 'max_params_in_decl', 'member_funs', 'member_vars', 'min_member_funs\n']

# %%
# y is vector of labels
def create_labels(y):
    y_l = np.copy(y)
    for i in range(y.shape[0]):
        if y[i] >= 80: 
            y_l[i] = 5
        if y[i] >= 60 and y[i] < 80: 
            y_l[i] = 4
        if y[i] >= 40 and y[i] < 60:
            y_l[i] = 3
        if y[i] >= 20 and y[i] < 40:
            y_l[i] = 2
        if y[i] < 20: 
            y_l[i] = 1
    return y_l

# %%
# training and test split
import random
def createTrainTestSplit():
    cnt_train = int(0.8 * len(authors)) + 1

    train_authors_indices = set()

    while len(train_authors_indices) < cnt_train:
        train_authors_indices.add(random.randint(0, len(authors) - 1))

    test_authors_indices = set()

    for i in range(len(authors)):
        if i not in train_authors_indices:
            test_authors_indices.add(i)

    train_authors = [authors[i] for i in train_authors_indices]

    test_authors = [authors[i] for i in test_authors_indices]
    
    X_train_list = []
    y_train_list = []
    X_test_list = []
    y_test_list = []

    for index in train_authors_indices:
        X_train_list.extend(features[index])
        y_train_list.extend(scores[index])

    for index in test_authors_indices:
        X_test_list.extend(features[index])
        y_test_list.extend(scores[index])

    X_train = np.asarray(X_train_list)
    y_train = np.asarray(y_train_list)
    X_test = np.asarray(X_test_list)
    y_test = np.asarray(y_test_list)
    
    y_train = create_labels(y_train) 
    y_test = create_labels(y_test)
    
    return X_train, y_train, X_test, y_test

# %%
X_train, y_train, X_test, y_test = createTrainTestSplit()
print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (14817, 34) (14817,) (3850, 34) (3850,)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X_train, y_train)

print (clf.score(X_test, y_test))
# Out:
# 0.251948051948

# %%
from sklearn.ensemble import AdaBoostClassifier
abc = AdaBoostClassifier()
abc.fit(X_train, y_train)
print (abc.score(X_test, y_test))
# Out:
# 0.291168831169

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(X_train, y_train)
print (gbc.score(X_test, y_test))
# Out:
# 0.376623376623

# %%
from sklearn.neighbors import KNeighborsClassifier

for n in range(1, 11):
    neigh = KNeighborsClassifier(n_neighbors=n)
    neigh.fit(X_train, y_train)
    print ('neighbors', n, "score", neigh.score(X_test, y_test))
# Out:
# neighbors 1 score 0.701038961039
# neighbors 2 score 0.648571428571
# neighbors 3 score 0.596363636364
# neighbors 4 score 0.447272727273
# neighbors 5 score 0.39974025974
# neighbors 6 score 0.370649350649
# neighbors 7 score 0.367532467532
# neighbors 8 score 0.354285714286
# neighbors 9 score 0.351948051948
# neighbors 10 score 0.345194805195

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier(n_estimators=30)
etc.fit(X_train, y_train)
print (etc.score(X_test, y_test))
# Out:
# 0.701558441558

# %%
from sklearn import tree
dtc = tree.DecisionTreeClassifier()
dtc.fit(X_train, y_train)
print (dtc.score(X_test, y_test))
# Out:
# 0.697922077922

# %%
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    print ("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print ("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print ("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)

# %%
tree_to_code(dtc, labels)
# Out:
# def tree(number_of_modules, lines_of_code, lines_of_code_per_module, McCabes_cyclomatic_complexity, McCabes_cyclomatic_complexity_per_module, lines_of_comment, lines_of_comment_per_module, lines_of_code_per_line_of_comment, McCabes_cyclomatic_complexity_per_line_of_comment, IF4, IF4_per_module, IF4_visible, IF4_visible_per_module, IF4_concrete, IF4_concrete, rejected_lines_of_code
# , Files, Lines, AVG Len, Code, Comments, White SP, Cd/Cm+WS, Cd/Cm, Cd/WS, % Code, cnt_classes, max_member_funs, max_nested_loops, max_nesting_depth, max_params_in_decl, member_funs, member_vars, min_member_funs
# ):
#   if rejected_lines_of_code
#  <= 1.5:
#     if McCabes_cyclomatic_complexity_per_module <= 25.5:
#       if Comments <= 2.5:
#         if % Code <= 0.9449999928474426:
#           if lines_of_code_per_module <= 44.5:
#             if lines_of_code_per_module <= 28.75:
#               if lines_of_code_per_module <= 22.5:
#                 if max_params_in_decl <= 1.5:
#                   if Cd/Cm <= 42.5:
#                     if McCabes_cyclomatic_complexity <= 5.5:
#                       if Lines <= 19.5:
#                         if lines_of_code <= 13.5:
#                           if Cd/WS <= 4.835000038146973:
#                             if lines_of_code_per_module <= 11.5:
#                               if McCabes_cyclomatic_complexity <= 1.5:
#                                 if White SP <= 1.5:
#                                   return [[ 1.  0.  0.  0.  0.]]
#                                 else:  # if White SP > 1.5
#                                   return [[ 0.  0.  0.  0.  2.]]
#                               else:  # if McCabes_cyclomatic_complexity > 1.5
#                                 return [[  0.   0.  10.   0.   0.]]
#                             else:  # if lines_of_code_per_module > 11.5
#                               if White SP <= 3.5:
#                                 if max_nested_loops <= 1.5:
#                                   return [[ 0.  0.  0.  0.  6.]]
#                                 else:  # if max_nested_loops > 1.5
#                                   return [[ 0.  0.  2.  0.  0.]]
#                               else:  # if White SP > 3.5
#                                 return [[ 0.  0.  0.  2.  0.]]
#                           else:  # if Cd/WS > 4.835000038146973
#                             if AVG Len <= 14.5:
#                               if % Code <= 0.8999999761581421:
#                                 return [[ 1.  0.  0.  0.  0.]]
#                               else:  # if % Code > 0.8999999761581421
#                                 return [[ 0.  0.  0.  0.  2.]]
#                             else:  # if AVG Len > 14.5
#                               if lines_of_comment_per_module <= 0.5:
#                                 if max_nested_loops <= 1.5:
#                                   if Cd/Cm+WS <= 8.0:
#                                     if % Code <= 0.875:
#                                       if Lines <= 12.5:
#                                         return [[ 0.  4.  0.  0.  0.]]
#                                       else:  # if Lines > 12.5
#                                         if lines_of_code_per_module <= 10.5:
#                                           return [[ 0.  0.  0.  2.  0.]]
#                                         else:  # if lines_of_code_per_module > 10.5
#                                           return [[ 0.  2.  0.  0.  0.]]
#                                     else:  # if % Code > 0.875
#                                       return [[ 0.  0.  0.  0.  2.]]
#                                   else:  # if Cd/Cm+WS > 8.0
#                                     return [[ 0.  8.  0.  0.  0.]]
#                                 else:  # if max_nested_loops > 1.5
#                                   return [[ 0.  0.  0.  1.  0.]]
#                               else:  # if lines_of_comment_per_module > 0.5
#                                 return [[ 0.  0.  0.  0.  2.]]
#                         else:  # if lines_of_code > 13.5
#                           if max_nesting_depth <= 2.5:
#                             if AVG Len <= 19.5:
#                               if Cd/Cm+WS <= 4.539999961853027:
#                                 return [[ 0.  0.  0.  0.  2.]]
#                               else:  # if Cd/Cm+WS > 4.539999961853027
#                                 return [[  0.   0.   0.  24.   0.]]
#                             else:  # if AVG Len > 19.5
#                               return [[ 0.  0.  0.  0.  6.]]
#                           else:  # if max_nesting_depth > 2.5
#                             if lines_of_code_per_module <= 15.5:
#                               return [[  0.   0.   0.   0.  10.]]
#                             else:  # if lines_of_code_per_module > 15.5
#                               if McCabes_cyclomatic_complexity <= 4.5:
#                                 return [[ 0.  2.  0.  0.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity > 4.5
#                                 if Lines <= 18.5:
#                                   return [[ 0.  0.  0.  0.  2.]]
#                                 else:  # if Lines > 18.5
#                                   return [[ 0.  0.  0.  1.  0.]]
#                       else:  # if Lines > 19.5
#                         if % Code <= 0.8849999904632568:
#                           if Cd/WS <= 4.324999809265137:
#                             if max_params_in_decl <= 0.5:
#                               if AVG Len <= 18.5:
#                                 if Cd/Cm+WS <= 2.690000057220459:
#                                   if White SP <= 6.5:
#                                     return [[ 0.  0.  0.  6.  0.]]
#                                   else:  # if White SP > 6.5
#                                     if % Code <= 0.7150000333786011:
#                                       if McCabes_cyclomatic_complexity <= 3.5:
#                                         if max_nesting_depth <= 2.5:
#                                           if Code <= 16.5:
#                                             return [[ 0.  2.  0.  0.  0.]]
#                                           else:  # if Code > 16.5
#                                             return [[ 0.  0.  4.  0.  0.]]
#                                         else:  # if max_nesting_depth > 2.5
#                                           return [[ 0.  5.  0.  0.  0.]]
#                                       else:  # if McCabes_cyclomatic_complexity > 3.5
#                                         if Code <= 20.5:
#                                           return [[ 0.  2.  0.  0.  0.]]
#                                         else:  # if Code > 20.5
#                                           return [[ 0.  0.  0.  6.  0.]]
#                                     else:  # if % Code > 0.7150000333786011
#                                       return [[ 0.  0.  6.  0.  0.]]
#                                 else:  # if Cd/Cm+WS > 2.690000057220459
#                                   if % Code <= 0.7749999761581421:
#                                     if AVG Len <= 13.5:
#                                       if lines_of_code <= 18.5:
#                                         return [[ 0.  5.  0.  0.  0.]]
#                                       else:  # if lines_of_code > 18.5
#                                         if lines_of_code <= 21.5:
#                                           if McCabes_cyclomatic_complexity <= 3.5:
#                                             return [[ 0.  0.  0.  0.  2.]]
#                                           else:  # if McCabes_cyclomatic_complexity > 3.5
#                                             return [[ 2.  0.  0.  0.  0.]]
#                                         else:  # if lines_of_code > 21.5
#                                           return [[ 0.  0.  0.  2.  0.]]
#                                     else:  # if AVG Len > 13.5
#                                       return [[  0.  16.   0.   0.   0.]]
#                                   else:  # if % Code > 0.7749999761581421
#                                     if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                       return [[ 0.  0.  0.  3.  0.]]
#                                     else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                       if AVG Len <= 12.0:
#                                         return [[ 0.  0.  2.  0.  0.]]
#                                       else:  # if AVG Len > 12.0
#                                         if Lines <= 25.5:
#                                           return [[ 0.  2.  0.  0.  0.]]
#                                         else:  # if Lines > 25.5
#                                           if lines_of_code_per_module <= 18.5:
#                                             return [[ 0.  0.  0.  0.  2.]]
#                                           else:  # if lines_of_code_per_module > 18.5
#                                             return [[ 2.  0.  0.  0.  0.]]
#                               else:  # if AVG Len > 18.5
#                                 if Cd/WS <= 3.7649998664855957:
#                                   if lines_of_code_per_line_of_comment <= 5.25:
#                                     if Cd/Cm <= 27.0:
#                                       return [[ 0.  0.  8.  0.  0.]]
#                                     else:  # if Cd/Cm > 27.0
#                                       return [[ 0.  0.  0.  2.  0.]]
#                                   else:  # if lines_of_code_per_line_of_comment > 5.25
#                                     return [[ 0.  0.  0.  0.  2.]]
#                                 else:  # if Cd/WS > 3.7649998664855957
#                                   return [[ 0.  0.  0.  0.  5.]]
#                             else:  # if max_params_in_decl > 0.5
#                               if lines_of_code_per_module <= 18.5:
#                                 return [[  0.   0.  10.   0.   0.]]
#                               else:  # if lines_of_code_per_module > 18.5
#                                 if Code <= 23.5:
#                                   return [[ 0.  1.  0.  0.  0.]]
#                                 else:  # if Code > 23.5
#                                   return [[ 1.  0.  0.  0.  0.]]
#                           else:  # if Cd/WS > 4.324999809265137
#                             if Cd/WS <= 4.550000190734863:
#                               return [[ 0.  0.  0.  0.  8.]]
#                             else:  # if Cd/WS > 4.550000190734863
#                               if Cd/Cm+WS <= 5.289999961853027:
#                                 if lines_of_code_per_line_of_comment <= 16.5:
#                                   if AVG Len <= 13.5:
#                                     if lines_of_code <= 17.0:
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                     else:  # if lines_of_code > 17.0
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                   else:  # if AVG Len > 13.5
#                                     if Cd/WS <= 4.775000095367432:
#                                       if % Code <= 0.824999988079071:
#                                         return [[ 0.  2.  0.  0.  0.]]
#                                       else:  # if % Code > 0.824999988079071
#                                         return [[ 1.  0.  0.  0.  0.]]
#                                     else:  # if Cd/WS > 4.775000095367432
#                                       if AVG Len <= 16.5:
#                                         return [[  0.   0.   0.  16.   0.]]
#                                       else:  # if AVG Len > 16.5
#                                         if lines_of_code_per_module <= 20.5:
#                                           if % Code <= 0.8349999785423279:
#                                             return [[ 0.  0.  0.  8.  0.]]
#                                           else:  # if % Code > 0.8349999785423279
#                                             return [[ 0.  0.  1.  0.  0.]]
#                                         else:  # if lines_of_code_per_module > 20.5
#                                           return [[ 0.  2.  0.  0.  0.]]
#                                 else:  # if lines_of_code_per_line_of_comment > 16.5
#                                   return [[ 0.  0.  0.  0.  4.]]
#                               else:  # if Cd/Cm+WS > 5.289999961853027
#                                 if Cd/WS <= 5.940000057220459:
#                                   if Cd/WS <= 5.414999961853027:
#                                     return [[ 0.  0.  2.  0.  0.]]
#                                   else:  # if Cd/WS > 5.414999961853027
#                                     return [[ 0.  0.  0.  0.  7.]]
#                                 else:  # if Cd/WS > 5.940000057220459
#                                   if Lines <= 26.5:
#                                     if lines_of_code <= 21.0:
#                                       if Code <= 18.5:
#                                         if McCabes_cyclomatic_complexity_per_module <= 4.0:
#                                           return [[ 0.  0.  0.  4.  0.]]
#                                         else:  # if McCabes_cyclomatic_complexity_per_module > 4.0
#                                           return [[ 0.  1.  0.  0.  0.]]
#                                       else:  # if Code > 18.5
#                                         if lines_of_code <= 17.5:
#                                           return [[ 0.  0.  3.  0.  0.]]
#                                         else:  # if lines_of_code > 17.5
#                                           if McCabes_cyclomatic_complexity <= 3.5:
#                                             if max_params_in_decl <= 0.5:
#                                               if lines_of_code <= 19.5:
#                                                 return [[ 0.  3.  0.  0.  0.]]
#                                               else:  # if lines_of_code > 19.5
#                                                 return [[ 1.  0.  0.  0.  0.]]
#                                             else:  # if max_params_in_decl > 0.5
#                                               return [[ 0.  0.  0.  0.  2.]]
#                                           else:  # if McCabes_cyclomatic_complexity > 3.5
#                                             if lines_of_code <= 18.5:
#                                               return [[ 0.  0.  1.  0.  0.]]
#                                             else:  # if lines_of_code > 18.5
#                                               return [[ 0.  0.  0.  0.  6.]]
#                                     else:  # if lines_of_code > 21.0
#                                       if McCabes_cyclomatic_complexity <= 4.0:
#                                         return [[ 0.  1.  0.  0.  0.]]
#                                       else:  # if McCabes_cyclomatic_complexity > 4.0
#                                         return [[ 0.  0.  0.  4.  0.]]
#                                   else:  # if Lines > 26.5
#                                     if Cd/Cm+WS <= 6.914999961853027:
#                                       return [[  0.  10.   0.   0.   0.]]
#                                     else:  # if Cd/Cm+WS > 6.914999961853027
#                                       return [[ 0.  0.  0.  2.  0.]]
#                         else:  # if % Code > 0.8849999904632568
#                           if Cd/WS <= 12.25:
#                             if Lines <= 23.0:
#                               if AVG Len <= 17.5:
#                                 if AVG Len <= 14.5:
#                                   if Lines <= 21.5:
#                                     return [[ 0.  2.  0.  0.  0.]]
#                                   else:  # if Lines > 21.5
#                                     return [[ 0.  0.  0.  0.  2.]]
#                                 else:  # if AVG Len > 14.5
#                                   if lines_of_code_per_module <= 16.0:
#                                     if rejected_lines_of_code
#  <= 0.5:
#                                       return [[ 0.  0.  0.  4.  0.]]
#                                     else:  # if rejected_lines_of_code
#  > 0.5
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                   else:  # if lines_of_code_per_module > 16.0
#                                     if max_params_in_decl <= 0.5:
#                                       return [[ 0.  0.  5.  0.  0.]]
#                                     else:  # if max_params_in_decl > 0.5
#                                       return [[ 0.  1.  0.  0.  0.]]
#                               else:  # if AVG Len > 17.5
#                                 return [[ 0.  6.  0.  0.  0.]]
#                             else:  # if Lines > 23.0
#                               if McCabes_cyclomatic_complexity <= 1.5:
#                                 return [[ 1.  0.  0.  0.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity > 1.5
#                                 if McCabes_cyclomatic_complexity <= 3.5:
#                                   return [[  0.   0.  22.   0.   0.]]
#                                 else:  # if McCabes_cyclomatic_complexity > 3.5
#                                   if AVG Len <= 17.0:
#                                     if lines_of_code_per_module <= 21.5:
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                     else:  # if lines_of_code_per_module > 21.5
#                                       return [[ 0.  0.  0.  2.  0.]]
#                                   else:  # if AVG Len > 17.0
#                                     return [[ 0.  0.  8.  0.  0.]]
#                           else:  # if Cd/WS > 12.25
#                             if lines_of_code <= 17.5:
#                               return [[ 0.  3.  0.  0.  0.]]
#                             else:  # if lines_of_code > 17.5
#                               if Lines <= 37.0:
#                                 return [[ 3.  0.  0.  0.  0.]]
#                               else:  # if Lines > 37.0
#                                 return [[ 0.  0.  0.  0.  2.]]
#                     else:  # if McCabes_cyclomatic_complexity > 5.5
#                       if max_nesting_depth <= 2.5:
#                         if AVG Len <= 14.5:
#                           return [[ 0.  0.  0.  5.  0.]]
#                         else:  # if AVG Len > 14.5
#                           if AVG Len <= 17.5:
#                             if White SP <= 14.5:
#                               if Cd/WS <= 8.274999618530273:
#                                 return [[ 0.  0.  9.  0.  0.]]
#                               else:  # if Cd/WS > 8.274999618530273
#                                 return [[ 1.  0.  2.  0.  0.]]
#                             else:  # if White SP > 14.5
#                               return [[ 0.  1.  0.  0.  0.]]
#                           else:  # if AVG Len > 17.5
#                             if Comments <= 0.5:
#                               if Lines <= 23.5:
#                                 return [[ 1.  0.  0.  0.  0.]]
#                               else:  # if Lines > 23.5
#                                 return [[ 0.  0.  0.  0.  4.]]
#                             else:  # if Comments > 0.5
#                               if Code <= 25.5:
#                                 return [[ 0.  0.  1.  0.  0.]]
#                               else:  # if Code > 25.5
#                                 return [[ 1.  0.  0.  0.  0.]]
#                       else:  # if max_nesting_depth > 2.5
#                         if Cd/Cm <= 11.25:
#                           if Cd/Cm+WS <= 10.75:
#                             if Code <= 24.5:
#                               return [[  0.   0.   0.  20.   0.]]
#                             else:  # if Code > 24.5
#                               if Cd/Cm+WS <= 8.414999961853027:
#                                 if Lines <= 29.5:
#                                   return [[ 0.  0.  0.  0.  2.]]
#                                 else:  # if Lines > 29.5
#                                   if member_funs <= 5.0:
#                                     return [[ 1.  0.  0.  0.  0.]]
#                                   else:  # if member_funs > 5.0
#                                     return [[ 0.  1.  0.  0.  0.]]
#                               else:  # if Cd/Cm+WS > 8.414999961853027
#                                 return [[ 0.  0.  0.  4.  0.]]
#                           else:  # if Cd/Cm+WS > 10.75
#                             return [[ 0.  0.  0.  0.  2.]]
#                         else:  # if Cd/Cm > 11.25
#                           if Cd/WS <= 11.75:
#                             return [[ 0.  0.  0.  0.  3.]]
#                           else:  # if Cd/WS > 11.75
#                             if Cd/Cm+WS <= 6.835000038146973:
#                               return [[ 1.  0.  0.  0.  0.]]
#                             else:  # if Cd/Cm+WS > 6.835000038146973
#                               return [[ 0.  0.  1.  0.  0.]]
#                   else:  # if Cd/Cm > 42.5
#                     return [[ 0.  7.  0.  0.  0.]]
#                 else:  # if max_params_in_decl > 1.5
#                   if % Code <= 0.8349999785423279:
#                     if White SP <= 6.5:
#                       return [[ 0.  3.  0.  0.  0.]]
#                     else:  # if White SP > 6.5
#                       if max_params_in_decl <= 2.5:
#                         if Code <= 97.5:
#                           if lines_of_code <= 20.5:
#                             return [[  0.   0.  10.   0.   0.]]
#                           else:  # if lines_of_code > 20.5
#                             return [[ 0.  0.  0.  1.  0.]]
#                         else:  # if Code > 97.5
#                           return [[ 2.  0.  0.  0.  0.]]
#                       else:  # if max_params_in_decl > 2.5
#                         if White SP <= 17.5:
#                           return [[ 2.  0.  0.  0.  0.]]
#                         else:  # if White SP > 17.5
#                           return [[ 0.  0.  0.  0.  2.]]
#                   else:  # if % Code > 0.8349999785423279
#                     if AVG Len <= 21.0:
#                       if McCabes_cyclomatic_complexity <= 1.0:
#                         return [[ 0.  0.  2.  0.  0.]]
#                       else:  # if McCabes_cyclomatic_complexity > 1.0
#                         if max_params_in_decl <= 3.5:
#                           return [[  0.   0.   0.   0.  28.]]
#                         else:  # if max_params_in_decl > 3.5
#                           return [[ 0.  1.  0.  0.  0.]]
#                     else:  # if AVG Len > 21.0
#                       if max_nested_loops <= 2.5:
#                         return [[ 4.  0.  0.  0.  0.]]
#                       else:  # if max_nested_loops > 2.5
#                         return [[ 0.  0.  0.  1.  0.]]
#               else:  # if lines_of_code_per_module > 22.5
#                 if Cd/Cm+WS <= 3.7249999046325684:
#                   if Cd/WS <= 1.4300000667572021:
#                     return [[ 0.  8.  0.  0.  0.]]
#                   else:  # if Cd/WS > 1.4300000667572021
#                     if Lines <= 48.5:
#                       if Cd/Cm <= 15.75:
#                         if lines_of_code_per_line_of_comment <= 12.25:
#                           if max_nesting_depth <= 2.5:
#                             if lines_of_code <= 25.0:
#                               return [[ 0.  4.  0.  0.  0.]]
#                             else:  # if lines_of_code > 25.0
#                               if Lines <= 43.5:
#                                 return [[ 0.  0.  0.  1.  0.]]
#                               else:  # if Lines > 43.5
#                                 return [[ 0.  0.  0.  0.  2.]]
#                           else:  # if max_nesting_depth > 2.5
#                             if max_nested_loops <= 2.5:
#                               if McCabes_cyclomatic_complexity <= 4.5:
#                                 if AVG Len <= 12.5:
#                                   return [[ 0.  0.  0.  0.  2.]]
#                                 else:  # if AVG Len > 12.5
#                                   return [[ 0.  0.  0.  2.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity > 4.5
#                                 if Code <= 30.5:
#                                   if Cd/Cm+WS <= 3.1100001335144043:
#                                     return [[ 0.  0.  0.  9.  0.]]
#                                   else:  # if Cd/Cm+WS > 3.1100001335144043
#                                     if % Code <= 0.7699999809265137:
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                     else:  # if % Code > 0.7699999809265137
#                                       return [[ 0.  0.  0.  4.  0.]]
#                                 else:  # if Code > 30.5
#                                   return [[ 1.  0.  0.  0.  0.]]
#                             else:  # if max_nested_loops > 2.5
#                               if Code <= 28.5:
#                                 return [[ 0.  0.  3.  0.  0.]]
#                               else:  # if Code > 28.5
#                                 if McCabes_cyclomatic_complexity_per_module <= 6.5:
#                                   return [[ 0.  0.  0.  2.  0.]]
#                                 else:  # if McCabes_cyclomatic_complexity_per_module > 6.5
#                                   return [[ 0.  3.  0.  0.  0.]]
#                         else:  # if lines_of_code_per_line_of_comment > 12.25
#                           if lines_of_code <= 27.5:
#                             return [[ 3.  0.  0.  0.  0.]]
#                           else:  # if lines_of_code > 27.5
#                             return [[ 0.  0.  2.  0.  0.]]
#                       else:  # if Cd/Cm > 15.75
#                         return [[  0.   0.   0.  13.   0.]]
#                     else:  # if Lines > 48.5
#                       if Lines <= 53.0:
#                         return [[ 0.  0.  7.  0.  0.]]
#                       else:  # if Lines > 53.0
#                         return [[ 3.  0.  0.  0.  0.]]
#                 else:  # if Cd/Cm+WS > 3.7249999046325684
#                   if max_nesting_depth <= 3.5:
#                     if AVG Len <= 21.5:
#                       if Lines <= 34.5:
#                         if Cd/Cm <= 27.5:
#                           if AVG Len <= 11.5:
#                             if rejected_lines_of_code
#  <= 0.5:
#                               if lines_of_code_per_module <= 24.5:
#                                 if Lines <= 27.0:
#                                   return [[ 0.  0.  0.  2.  0.]]
#                                 else:  # if Lines > 27.0
#                                   return [[ 0.  2.  0.  0.  0.]]
#                               else:  # if lines_of_code_per_module > 24.5
#                                 return [[ 0.  0.  0.  2.  0.]]
#                             else:  # if rejected_lines_of_code
#  > 0.5
#                               if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                 return [[ 0.  2.  0.  0.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                 return [[ 0.  0.  0.  0.  4.]]
#                           else:  # if AVG Len > 11.5
#                             if AVG Len <= 13.5:
#                               if Lines <= 33.0:
#                                 if rejected_lines_of_code
#  <= 0.5:
#                                   if Code <= 28.5:
#                                     return [[ 0.  0.  7.  0.  0.]]
#                                   else:  # if Code > 28.5
#                                     return [[ 0.  2.  0.  0.  0.]]
#                                 else:  # if rejected_lines_of_code
#  > 0.5
#                                   return [[ 0.  0.  0.  0.  2.]]
#                               else:  # if Lines > 33.0
#                                 return [[  0.   0.  13.   0.   0.]]
#                             else:  # if AVG Len > 13.5
#                               if AVG Len <= 17.5:
#                                 if Lines <= 28.5:
#                                   if lines_of_code <= 23.5:
#                                     return [[ 0.  0.  0.  8.  0.]]
#                                   else:  # if lines_of_code > 23.5
#                                     return [[ 0.  2.  0.  0.  0.]]
#                                 else:  # if Lines > 28.5
#                                   if Code <= 29.5:
#                                     if Lines <= 29.5:
#                                       return [[ 0.  6.  0.  0.  0.]]
#                                     else:  # if Lines > 29.5
#                                       if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                                         return [[ 0.  4.  0.  0.  0.]]
#                                       else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                                         if McCabes_cyclomatic_complexity_per_module <= 5.5:
#                                           if lines_of_code_per_line_of_comment <= 24.5:
#                                             if max_params_in_decl <= 0.5:
#                                               return [[  0.   0.  17.   0.   0.]]
#                                             else:  # if max_params_in_decl > 0.5
#                                               return [[ 1.  0.  0.  0.  0.]]
#                                           else:  # if lines_of_code_per_line_of_comment > 24.5
#                                             return [[ 0.  0.  0.  2.  0.]]
#                                         else:  # if McCabes_cyclomatic_complexity_per_module > 5.5
#                                           if Code <= 27.5:
#                                             if AVG Len <= 16.0:
#                                               return [[ 0.  0.  0.  4.  0.]]
#                                             else:  # if AVG Len > 16.0
#                                               return [[ 0.  0.  2.  0.  0.]]
#                                           else:  # if Code > 27.5
#                                             if McCabes_cyclomatic_complexity_per_module <= 9.0:
#                                               if McCabes_cyclomatic_complexity_per_module <= 6.5:
#                                                 return [[ 0.  4.  0.  0.  0.]]
#                                               else:  # if McCabes_cyclomatic_complexity_per_module > 6.5
#                                                 if lines_of_code_per_module <= 26.5:
#                                                   return [[ 0.  0.  1.  0.  0.]]
#                                                 else:  # if lines_of_code_per_module > 26.5
#                                                   return [[ 0.  2.  0.  0.  0.]]
#                                             else:  # if McCabes_cyclomatic_complexity_per_module > 9.0
#                                               return [[ 2.  0.  0.  0.  0.]]
#                                   else:  # if Code > 29.5
#                                     return [[ 0.  8.  0.  0.  0.]]
#                               else:  # if AVG Len > 17.5
#                                 if Cd/Cm <= 14.5:
#                                   if AVG Len <= 18.5:
#                                     if Cd/Cm+WS <= 8.664999961853027:
#                                       return [[ 0.  0.  3.  0.  0.]]
#                                     else:  # if Cd/Cm+WS > 8.664999961853027
#                                       return [[ 4.  0.  0.  0.  0.]]
#                                   else:  # if AVG Len > 18.5
#                                     if Cd/Cm+WS <= 7.625:
#                                       if lines_of_code <= 25.5:
#                                         if rejected_lines_of_code
#  <= 0.5:
#                                           return [[ 0.  0.  1.  0.  0.]]
#                                         else:  # if rejected_lines_of_code
#  > 0.5
#                                           return [[ 0.  0.  0.  4.  0.]]
#                                       else:  # if lines_of_code > 25.5
#                                         return [[ 0.  0.  2.  0.  0.]]
#                                     else:  # if Cd/Cm+WS > 7.625
#                                       if rejected_lines_of_code
#  <= 0.5:
#                                         if Cd/WS <= 8.835000038146973:
#                                           return [[ 0.  0.  3.  0.  0.]]
#                                         else:  # if Cd/WS > 8.835000038146973
#                                           return [[ 0.  0.  0.  0.  3.]]
#                                       else:  # if rejected_lines_of_code
#  > 0.5
#                                         return [[  0.   0.  10.   0.   0.]]
#                                 else:  # if Cd/Cm > 14.5
#                                   return [[ 0.  2.  0.  0.  0.]]
#                         else:  # if Cd/Cm > 27.5
#                           if rejected_lines_of_code
#  <= 0.5:
#                             return [[ 0.  7.  0.  0.  0.]]
#                           else:  # if rejected_lines_of_code
#  > 0.5
#                             if Cd/Cm+WS <= 9.664999961853027:
#                               return [[ 0.  0.  0.  2.  0.]]
#                             else:  # if Cd/Cm+WS > 9.664999961853027
#                               return [[ 0.  0.  0.  0.  4.]]
#                       else:  # if Lines > 34.5
#                         if McCabes_cyclomatic_complexity_per_module <= 6.5:
#                           if Lines <= 66.5:
#                             if lines_of_code_per_line_of_comment <= 13.0:
#                               if AVG Len <= 18.5:
#                                 if Lines <= 37.5:
#                                   if Lines <= 36.5:
#                                     if AVG Len <= 14.5:
#                                       return [[  0.   0.  10.   0.   0.]]
#                                     else:  # if AVG Len > 14.5
#                                       if AVG Len <= 16.5:
#                                         if max_nesting_depth <= 2.5:
#                                           return [[ 0.  0.  1.  0.  0.]]
#                                         else:  # if max_nesting_depth > 2.5
#                                           return [[ 2.  0.  0.  0.  0.]]
#                                       else:  # if AVG Len > 16.5
#                                         return [[ 0.  0.  6.  0.  0.]]
#                                   else:  # if Lines > 36.5
#                                     return [[ 1.  0.  0.  0.  0.]]
#                                 else:  # if Lines > 37.5
#                                   return [[  0.   0.  19.   0.   0.]]
#                               else:  # if AVG Len > 18.5
#                                 if Cd/Cm+WS <= 7.699999809265137:
#                                   return [[ 0.  0.  6.  0.  0.]]
#                                 else:  # if Cd/Cm+WS > 7.699999809265137
#                                   return [[ 0.  2.  0.  0.  0.]]
#                             else:  # if lines_of_code_per_line_of_comment > 13.0
#                               if McCabes_cyclomatic_complexity <= 4.5:
#                                 if Cd/WS <= 7.300000190734863:
#                                   return [[ 1.  0.  0.  0.  0.]]
#                                 else:  # if Cd/WS > 7.300000190734863
#                                   return [[ 0.  0.  0.  4.  0.]]
#                               else:  # if McCabes_cyclomatic_complexity > 4.5
#                                 return [[ 0.  0.  6.  0.  0.]]
#                           else:  # if Lines > 66.5
#                             return [[ 0.  0.  0.  0.  2.]]
#                         else:  # if McCabes_cyclomatic_complexity_per_module > 6.5
#                           if lines_of_code_per_line_of_comment <= 13.5:
#                             if Lines <= 36.0:
#                               return [[ 0.  0.  3.  0.  0.]]
#                             else:  # if Lines > 36.0
#                               if Cd/Cm+WS <= 8.225000381469727:
#                                 return [[ 0.  0.  0.  8.  0.]]
#                               else:  # if Cd/Cm+WS > 8.225000381469727
#                                 return [[ 0.  0.  0.  0.  1.]]
#                           else:  # if lines_of_code_per_line_of_comment > 13.5
#                             if McCabes_cyclomatic_complexity_per_module <= 7.5:
#                               return [[ 0.  4.  0.  0.  0.]]
#                             else:  # if McCabes_cyclomatic_complexity_per_module > 7.5
#                               if Cd/Cm+WS <= 4.460000038146973:
#                                 return [[ 0.  0.  4.  0.  0.]]
#                               else:  # if Cd/Cm+WS > 4.460000038146973
#                                 if Cd/Cm <= 33.0:
#                                   return [[ 0.  0.  0.  0.  1.]]
#                                 else:  # if Cd/Cm > 33.0
#                                   return [[ 2.  0.  0.  0.  0.]]
#                     else:  # if AVG Len > 21.5
#                       if McCabes_cyclomatic_complexity <= 10.5:
#                         return [[  0.  10.   0.   0.   0.]]
#                       else:  # if McCabes_cyclomatic_complexity > 10.5
#                         return [[ 0.  0.  0.  2.  0.]]
#                   else:  # if max_nesting_depth > 3.5
#                     if AVG Len <= 17.5:
#                       if McCabes_cyclomatic_complexity <= 8.0:
#                         if rejected_lines_of_code
#  <= 0.5:
#                           return [[ 0.  0.  1.  0.  0.]]
#                         else:  # if rejected_lines_of_code
#  > 0.5
#                           return [[ 1.  0.  0.  0.  0.]]
#                       else:  # if McCabes_cyclomatic_complexity > 8.0
#                         return [[ 0.  0.  7.  0.  0.]]
#                     else:  # if AVG Len > 17.5
#                       if lines_of_code <= 25.5:
#                         if AVG Len <= 19.0:
#                           return [[ 0.  6.  0.  0.  0.]]
#                         else:  # if AVG Len > 19.0
#                           if Cd/Cm+WS <= 5.300000190734863:
#                             return [[ 0.  0.  0.  0.  2.]]
#                           else:  # if Cd/Cm+WS > 5.300000190734863
#                             return [[ 0.  0.  2.  0.  0.]]
#                       else:  # if lines_of_code > 25.5
#                         if Cd/WS <= 14.75:
#                           if AVG Len <= 21.5:
#                             return [[  0.   0.   0.   0.  14.]]
#                           else:  # if AVG Len > 21.5
#                             if Cd/WS <= 10.0:
#                               return [[ 0.  1.  0.  0.  0.]]
#                             else:  # if Cd/WS > 10.0
#                               return [[ 0.  0.  0.  0.  2.]]
#                         else:  # if Cd/WS > 14.75
#                           return [[ 0.  0.  1.  0.  0.]]
#             else:  # if lines_of_code_per_module > 28.75
#               if Cd/WS <= 19.5:
#                 if Code <= 69.0:
#                   if max_nested_loops <= 0.5:
#                     if Cd/Cm+WS <= 12.664999961853027:
#                       if Cd/Cm+WS <= 6.284999847412109:
#                         if max_params_in_decl <= 0.5:
#                           return [[ 0.  0.  0.  0.  6.]]
#                         else:  # if max_params_in_decl > 0.5
#                           if Cd/WS <= 2.9600000381469727:
#                             return [[ 0.  0.  0.  0.  2.]]
#                           else:  # if Cd/WS > 2.9600000381469727
#                             return [[ 0.  0.  0.  9.  0.]]
#                       else:  # if Cd/Cm+WS > 6.284999847412109
#                         if % Code <= 0.8899999856948853:
#                           return [[ 0.  0.  8.  0.  0.]]
#                         else:  # if % Code > 0.8899999856948853
#                           if McCabes_cyclomatic_complexity_per_module <= 3.5:
#                             return [[ 2.  0.  0.  0.  0.]]
#                           else:  # if McCabes_cyclomatic_complexity_per_module > 3.5
#                             return [[ 0.  0.  0.  0.  2.]]
#                     else:  # if Cd/Cm+WS > 12.664999961853027
#                       if lines_of_code <= 29.5:
#                         return [[ 1.  0.  0.  0.  0.]]
#                       else:  # if lines_of_code > 29.5
#                         return [[  0.   0.   0.  10.   0.]]
#                   else:  # if max_nested_loops > 0.5
#                     if Cd/Cm+WS <= 12.585000038146973:
#                       if Cd/WS <= 15.0:
#                         if Lines <= 51.5:
#                           if AVG Len <= 19.5:
#                             if Code <= 41.5:
#                               if McCabes_cyclomatic_complexity <= 4.5:
#                                 if Code <= 34.5:
#                                   return [[ 0.  0.  0.  0.  8.]]
#                                 else:  # if Code > 34.5
#                                   if Comments <= 1.5:
#                                     if max_params_in_decl <= 1.0:
#                                       return [[ 0.  0.  6.  0.  0.]]
#                                     else:  # if max_params_in_decl > 1.0
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                   else:  # if Comments > 1.5
#                                     return [[ 0.  0.  0.  0.  2.]]
#                               else:  # if McCabes_cyclomatic_complexity > 4.5
#                                 if lines_of_code <= 36.5:
#                                   if AVG Len <= 14.5:
#                                     if White SP <= 6.5:
#                                       if AVG Len <= 11.5:
#                                         if max_nesting_depth <= 2.5:
#                                           return [[ 0.  4.  0.  0.  0.]]
#                                         else:  # if max_nesting_depth > 2.5
#                                           if Cd/Cm+WS <= 5.489999771118164:
#                                             return [[ 0.  2.  0.  0.  0.]]
#                                           else:  # if Cd/Cm+WS > 5.489999771118164
#                                             return [[ 0.  0.  0.  6.  0.]]
#                                       else:  # if AVG Len > 11.5
#                                         if Cd/Cm+WS <= 6.664999961853027:
#                                           return [[  0.   0.  13.   0.   0.]]
#                                         else:  # if Cd/Cm+WS > 6.664999961853027
#                                           if rejected_lines_of_code
#  <= 0.5:
#                                             return [[ 0.  0.  5.  0.  0.]]
#                                           else:  # if rejected_lines_of_code
#  > 0.5
#                                             if AVG Len <= 13.5:
#                                               if Code <= 35.5:
#                                                 if McCabes_cyclomatic_complexity <= 5.5:
#                                                   return [[ 0.  1.  0.  0.  0.]]
#                                                 else:  # if McCabes_cyclomatic_complexity > 5.5
#                                                   return [[ 0.  0.  0.  2.  0.]]
#                                               else:  # if Code > 35.5
#                                                 return [[ 4.  0.  0.  0.  0.]]
#                                             else:  # if AVG Len > 13.5
#                                               if Cd/Cm+WS <= 9.960000038146973:
#                                                 return [[ 0.  0.  1.  0.  0.]]
#                                               else:  # if Cd/Cm+WS > 9.960000038146973
#                                                 return [[ 0.  0.  0.  0.  3.]]
#                                     else:  # if White SP > 6.5
#                                       if Lines <= 49.5:
#                                         if lines_of_code <= 33.5:
#                                           if Code <= 35.5:
#                                             return [[ 0.  0.  0.  7.  0.]]
#                                           else:  # if Code > 35.5
#                                             if White SP <= 9.0:
#                                               return [[ 0.  5.  0.  0.  0.]]
#                                             else:  # if White SP > 9.0
#                                               if McCabes_cyclomatic_complexity_per_line_of_comment <= 3.5:
#                                                 return [[ 0.  0.  0.  0.  2.]]
#                                               else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 3.5
#                                                 return [[ 1.  0.  0.  0.  0.]]
#                                         else:  # if lines_of_code > 33.5
#                                           if lines_of_code_per_line_of_comment <= 35.0:
#                                             return [[  0.   0.   0.  17.   0.]]
#                                           else:  # if lines_of_code_per_line_of_comment > 35.0
#                                             return [[ 0.  0.  1.  0.  0.]]
#                                       else:  # if Lines > 49.5
#                                         if Code <= 38.5:
#                                           if White SP <= 13.5:
#                                             return [[ 0.  0.  2.  0.  0.]]
#                                           else:  # if White SP > 13.5
#                                             return [[ 0.  2.  0.  0.  0.]]
#                                         else:  # if Code > 38.5
#                                           return [[ 0.  0.  0.  0.  4.]]
#                                   else:  # if AVG Len > 14.5
#                                     if lines_of_code_per_line_of_comment <= 23.75:
#                                       if AVG Len <= 17.5:
#                                         if McCabes_cyclomatic_complexity <= 9.5:
#                                           if Cd/Cm+WS <= 10.210000038146973:
#                                             if Cd/Cm <= 18.75:
#                                               if lines_of_code <= 31.5:
#                                                 if McCabes_cyclomatic_complexity <= 5.5:
#                                                   if Cd/Cm+WS <= 5.105000019073486:
#                                                     return [[ 0.  4.  0.  0.  0.]]
#                                                   else:  # if Cd/Cm+WS > 5.105000019073486
#                                                     return [[ 0.  0.  1.  0.  0.]]
#                                                 else:  # if McCabes_cyclomatic_complexity > 5.5
#                                                   return [[  0.  21.   0.   0.   0.]]
#                                               else:  # if lines_of_code > 31.5
#                                                 if Code <= 36.5:
#                                                   if McCabes_cyclomatic_complexity <= 7.5:
#                                                     if McCabes_cyclomatic_complexity_per_module <= 5.5:
#                                                       return [[ 1.  0.  0.  0.  0.]]
#                                                     else:  # if McCabes_cyclomatic_complexity_per_module > 5.5
#                                                       return [[ 0.  0.  2.  0.  0.]]
#                                                   else:  # if McCabes_cyclomatic_complexity > 7.5
#                                                     return [[ 0.  0.  0.  2.  0.]]
#                                                 else:  # if Code > 36.5
#                                                   return [[ 0.  9.  0.  0.  0.]]
#                                             else:  # if Cd/Cm > 18.75
#                                               return [[ 0.  0.  0.  2.  0.]]
#                                           else:  # if Cd/Cm+WS > 10.210000038146973
#                                             if lines_of_code <= 30.0:
# ...
#                                                 return [[ 0.  0.  3.  0.  0.]]
#                                       else:  # if lines_of_code_per_module > 142.5
#                                         if max_nesting_depth <= 4.5:
#                                           return [[ 0.  0.  0.  8.  0.]]
#                                         else:  # if max_nesting_depth > 4.5
#                                           return [[ 1.  0.  0.  0.  0.]]
#                                   else:  # if lines_of_comment > 10.5
#                                     if % Code <= 0.8349999785423279:
#                                       return [[ 0.  4.  0.  0.  0.]]
#                                     else:  # if % Code > 0.8349999785423279
#                                       if rejected_lines_of_code
#  <= 3.5:
#                                         return [[ 0.  2.  0.  0.  0.]]
#                                       else:  # if rejected_lines_of_code
#  > 3.5
#                                         return [[  0.   0.   0.  12.   0.]]
#                           else:  # if Cd/WS > 37.25
#                             if lines_of_code_per_line_of_comment <= 8.285500526428223:
#                               return [[ 0.  6.  0.  0.  0.]]
#                             else:  # if lines_of_code_per_line_of_comment > 8.285500526428223
#                               if AVG Len <= 19.5:
#                                 if Cd/WS <= 60.0:
#                                   if Cd/Cm+WS <= 17.825000762939453:
#                                     return [[  0.   0.   0.  16.   0.]]
#                                   else:  # if Cd/Cm+WS > 17.825000762939453
#                                     return [[ 0.  0.  2.  0.  0.]]
#                                 else:  # if Cd/WS > 60.0
#                                   if lines_of_code_per_line_of_comment <= 19.708499908447266:
#                                     if lines_of_code_per_line_of_comment <= 9.028499603271484:
#                                       return [[ 0.  0.  0.  0.  2.]]
#                                     else:  # if lines_of_code_per_line_of_comment > 9.028499603271484
#                                       return [[ 0.  0.  8.  0.  0.]]
#                                   else:  # if lines_of_code_per_line_of_comment > 19.708499908447266
#                                     if lines_of_code_per_module <= 90.5:
#                                       return [[ 0.  0.  0.  5.  0.]]
#                                     else:  # if lines_of_code_per_module > 90.5
#                                       if max_params_in_decl <= 2.5:
#                                         return [[ 0.  2.  0.  0.  0.]]
#                                       else:  # if max_params_in_decl > 2.5
#                                         return [[ 0.  0.  1.  0.  0.]]
#                               else:  # if AVG Len > 19.5
#                                 if % Code <= 0.9449999928474426:
#                                   if McCabes_cyclomatic_complexity_per_line_of_comment <= 1.633500099182129:
#                                     if lines_of_comment_per_module <= 7.0:
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                     else:  # if lines_of_comment_per_module > 7.0
#                                       return [[ 2.  0.  0.  0.  0.]]
#                                   else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 1.633500099182129
#                                     if lines_of_comment <= 9.5:
#                                       if Cd/Cm+WS <= 16.514999389648438:
#                                         if max_params_in_decl <= 2.5:
#                                           if rejected_lines_of_code
#  <= 2.5:
#                                             if lines_of_code_per_line_of_comment <= 14.833499908447266:
#                                               return [[ 0.  0.  2.  0.  0.]]
#                                             else:  # if lines_of_code_per_line_of_comment > 14.833499908447266
#                                               return [[ 0.  1.  0.  0.  0.]]
#                                           else:  # if rejected_lines_of_code
#  > 2.5
#                                             return [[  0.   0.  22.   0.   0.]]
#                                         else:  # if max_params_in_decl > 2.5
#                                           if rejected_lines_of_code
#  <= 11.5:
#                                             if Code <= 72.0:
#                                               return [[ 0.  0.  0.  1.  0.]]
#                                             else:  # if Code > 72.0
#                                               return [[ 0.  0.  0.  0.  2.]]
#                                           else:  # if rejected_lines_of_code
#  > 11.5
#                                             return [[ 0.  0.  4.  0.  0.]]
#                                       else:  # if Cd/Cm+WS > 16.514999389648438
#                                         if lines_of_code_per_line_of_comment <= 20.625:
#                                           return [[ 1.  0.  0.  0.  0.]]
#                                         else:  # if lines_of_code_per_line_of_comment > 20.625
#                                           return [[ 0.  1.  0.  0.  0.]]
#                                     else:  # if lines_of_comment > 9.5
#                                       return [[ 0.  0.  0.  2.  0.]]
#                                 else:  # if % Code > 0.9449999928474426
#                                   if % Code <= 0.9650000333786011:
#                                     if McCabes_cyclomatic_complexity_per_line_of_comment <= 6.583499908447266:
#                                       return [[ 0.  0.  0.  5.  0.]]
#                                     else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 6.583499908447266
#                                       if lines_of_code_per_line_of_comment <= 26.75:
#                                         return [[ 2.  0.  0.  0.  0.]]
#                                       else:  # if lines_of_code_per_line_of_comment > 26.75
#                                         return [[ 0.  0.  1.  0.  0.]]
#                                   else:  # if % Code > 0.9650000333786011
#                                     return [[ 0.  3.  0.  0.  0.]]
#                         else:  # if Cd/Cm > 49.25
#                           if AVG Len <= 17.5:
#                             if lines_of_code_per_line_of_comment <= 43.75:
#                               if White SP <= 15.0:
#                                 return [[ 0.  0.  2.  0.  0.]]
#                               else:  # if White SP > 15.0
#                                 return [[ 1.  0.  0.  0.  0.]]
#                             else:  # if lines_of_code_per_line_of_comment > 43.75
#                               if Cd/Cm+WS <= 5.920000076293945:
#                                 return [[ 0.  0.  2.  0.  0.]]
#                               else:  # if Cd/Cm+WS > 5.920000076293945
#                                 return [[  0.   0.   0.  14.   0.]]
#                           else:  # if AVG Len > 17.5
#                             if Cd/WS <= 7.069999694824219:
#                               if Cd/WS <= 6.215000152587891:
#                                 if max_params_in_decl <= 3.5:
#                                   if Lines <= 143.0:
#                                     return [[ 0.  0.  1.  0.  0.]]
#                                   else:  # if Lines > 143.0
#                                     return [[ 0.  1.  0.  0.  0.]]
#                                 else:  # if max_params_in_decl > 3.5
#                                   return [[ 0.  0.  0.  2.  0.]]
#                               else:  # if Cd/WS > 6.215000152587891
#                                 return [[ 0.  0.  0.  0.  3.]]
#                             else:  # if Cd/WS > 7.069999694824219
#                               if Cd/WS <= 51.5:
#                                 if lines_of_code <= 149.5:
#                                   if lines_of_code_per_module <= 122.0:
#                                     if McCabes_cyclomatic_complexity <= 52.5:
#                                       if lines_of_code_per_module <= 108.5:
#                                         return [[  0.   0.  24.   0.   0.]]
#                                       else:  # if lines_of_code_per_module > 108.5
#                                         if rejected_lines_of_code
#  <= 10.0:
#                                           return [[ 1.  0.  0.  0.  0.]]
#                                         else:  # if rejected_lines_of_code
#  > 10.0
#                                           return [[ 0.  0.  2.  0.  0.]]
#                                     else:  # if McCabes_cyclomatic_complexity > 52.5
#                                       return [[ 0.  1.  0.  0.  0.]]
#                                   else:  # if lines_of_code_per_module > 122.0
#                                     if rejected_lines_of_code
#  <= 11.5:
#                                       return [[ 0.  2.  0.  0.  0.]]
#                                     else:  # if rejected_lines_of_code
#  > 11.5
#                                       return [[ 0.  0.  2.  0.  0.]]
#                                 else:  # if lines_of_code > 149.5
#                                   return [[ 0.  0.  0.  0.  2.]]
#                               else:  # if Cd/WS > 51.5
#                                 return [[ 0.  0.  0.  0.  2.]]
#                       else:  # if Cd/Cm+WS > 31.25
#                         return [[  0.   0.   0.  14.   0.]]
#               else:  # if McCabes_cyclomatic_complexity > 61.0
#                 if Code <= 111.5:
#                   return [[ 0.  6.  0.  0.  0.]]
#                 else:  # if Code > 111.5
#                   if % Code <= 0.9449999928474426:
#                     if rejected_lines_of_code
#  <= 22.5:
#                       if McCabes_cyclomatic_complexity <= 110.0:
#                         if Cd/WS <= 5.939999580383301:
#                           return [[  0.   0.   0.  26.   0.]]
#                         else:  # if Cd/WS > 5.939999580383301
#                           if Cd/WS <= 13.279999732971191:
#                             if McCabes_cyclomatic_complexity <= 68.5:
#                               if lines_of_comment <= 3.5:
#                                 return [[ 0.  0.  0.  0.  2.]]
#                               else:  # if lines_of_comment > 3.5
#                                 if min_member_funs
#  <= 75002.0:
#                                   return [[ 1.  0.  0.  0.  0.]]
#                                 else:  # if min_member_funs
#  > 75002.0
#                                   return [[ 0.  1.  0.  0.  0.]]
#                             else:  # if McCabes_cyclomatic_complexity > 68.5
#                               return [[ 0.  0.  3.  0.  0.]]
#                           else:  # if Cd/WS > 13.279999732971191
#                             return [[  0.   0.   0.  10.   0.]]
#                       else:  # if McCabes_cyclomatic_complexity > 110.0
#                         return [[ 0.  2.  0.  0.  0.]]
#                     else:  # if rejected_lines_of_code
#  > 22.5
#                       return [[ 0.  4.  0.  0.  0.]]
#                   else:  # if % Code > 0.9449999928474426
#                     return [[ 0.  0.  0.  0.  4.]]
#             else:  # if lines_of_code_per_module > 145.5
#               if Cd/WS <= 5.940000057220459:
#                 if McCabes_cyclomatic_complexity_per_line_of_comment <= 4.390500068664551:
#                   if rejected_lines_of_code
#  <= 11.0:
#                     return [[ 0.  0.  0.  4.  0.]]
#                   else:  # if rejected_lines_of_code
#  > 11.0
#                     if % Code <= 0.699999988079071:
#                       return [[ 0.  0.  0.  0.  3.]]
#                     else:  # if % Code > 0.699999988079071
#                       if Cd/WS <= 5.054999828338623:
#                         return [[ 4.  0.  0.  0.  0.]]
#                       else:  # if Cd/WS > 5.054999828338623
#                         return [[ 0.  1.  0.  0.  0.]]
#                 else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 4.390500068664551
#                   if lines_of_comment <= 3.5:
#                     return [[ 1.  0.  0.  0.  0.]]
#                   else:  # if lines_of_comment > 3.5
#                     return [[  0.   0.   0.   0.  14.]]
#               else:  # if Cd/WS > 5.940000057220459
#                 if rejected_lines_of_code
#  <= 20.0:
#                   if Cd/WS <= 16.145000457763672:
#                     if lines_of_code_per_line_of_comment <= 27.916500091552734:
#                       if max_nested_loops <= 3.5:
#                         if Code <= 151.5:
#                           return [[ 0.  0.  1.  0.  0.]]
#                         else:  # if Code > 151.5
#                           return [[  0.  28.   0.   0.   0.]]
#                       else:  # if max_nested_loops > 3.5
#                         if McCabes_cyclomatic_complexity_per_line_of_comment <= 4.241499900817871:
#                           return [[ 0.  0.  0.  3.  0.]]
#                         else:  # if McCabes_cyclomatic_complexity_per_line_of_comment > 4.241499900817871
#                           return [[ 0.  0.  0.  0.  2.]]
#                     else:  # if lines_of_code_per_line_of_comment > 27.916500091552734
#                       if McCabes_cyclomatic_complexity_per_module <= 69.0:
#                         if max_nested_loops <= 4.0:
#                           return [[ 0.  0.  0.  0.  9.]]
#                         else:  # if max_nested_loops > 4.0
#                           return [[ 0.  0.  0.  2.  0.]]
#                       else:  # if McCabes_cyclomatic_complexity_per_module > 69.0
#                         if Lines <= 234.5:
#                           return [[ 0.  0.  4.  0.  0.]]
#                         else:  # if Lines > 234.5
#                           return [[ 0.  1.  0.  0.  0.]]
#                   else:  # if Cd/WS > 16.145000457763672
#                     if McCabes_cyclomatic_complexity <= 53.5:
#                       return [[ 0.  1.  0.  0.  0.]]
#                     else:  # if McCabes_cyclomatic_complexity > 53.5
#                       return [[  0.   0.   0.   0.  12.]]
#                 else:  # if rejected_lines_of_code
#  > 20.0
#                   if Comments <= 26.5:
#                     if lines_of_code_per_line_of_comment <= 20.20600128173828:
#                       return [[ 0.  0.  9.  0.  0.]]
#                     else:  # if lines_of_code_per_line_of_comment > 20.20600128173828
#                       return [[ 1.  0.  0.  0.  0.]]
#                   else:  # if Comments > 26.5
#                     return [[ 0.  2.  0.  0.  0.]]
#           else:  # if lines_of_comment > 100.5
#             if lines_of_comment_per_module <= 237.16650390625:
#               if Cd/Cm+WS <= 1.2649999856948853:
#                 if AVG Len <= 48.0:
#                   if lines_of_comment_per_module <= 156.33349609375:
#                     return [[  0.  17.   0.   0.   0.]]
#                   else:  # if lines_of_comment_per_module > 156.33349609375
#                     if lines_of_comment <= 565.5:
#                       return [[ 1.  0.  0.  0.  0.]]
#                     else:  # if lines_of_comment > 565.5
#                       return [[ 0.  2.  0.  0.  0.]]
#                 else:  # if AVG Len > 48.0
#                   return [[ 1.  0.  0.  0.  0.]]
#               else:  # if Cd/Cm+WS > 1.2649999856948853
#                 return [[ 0.  0.  0.  1.  0.]]
#             else:  # if lines_of_comment_per_module > 237.16650390625
#               return [[ 0.  0.  0.  5.  0.]]
#       else:  # if Cd/Cm > 190.5
#         if lines_of_code_per_line_of_comment <= 133.0:
#           return [[ 0.  0.  2.  0.  0.]]
#         else:  # if lines_of_code_per_line_of_comment > 133.0
#           if max_params_in_decl <= 4.5:
#             return [[  0.  19.   0.   0.   0.]]
#           else:  # if max_params_in_decl > 4.5
#             return [[ 1.  0.  0.  0.  0.]]

# %%
from sklearn.neural_network import MLPClassifier

alphas = [0.0001, 0.001, 0.01, 0.1]
solvers = ["adam", "lbfgs", "sgd"]
learning_rates = ["constant", "adaptive", "invscaling"]

for alpha in alphas:
    print("Alpha:\t", alpha)
    for solver in solvers:
        printf("Solver:\t%s\n", solver)
        for learning_rate in learning_rates:
            printf("Learning rate:\t%s\n", learning_rate)
            values = []
            for i in range(0, 5):
                X_train, y_train, X_test, y_test = createTrainTestSplit()
                mlpC = MLPClassifier(alpha=alpha, batch_size='auto', learning_rate=learning_rate, learning_rate_init=0.01, power_t=0.5, shuffle=True, max_iter=500)
                mlpC.fit(X_train, y_train)
                values.append(mlpC.score(X_test, y_test))
                
            values.sort()
            print("Median:", values[2])
            print("Average:", sum(values) / 5)
            print("Min:", min(values))
            print("Max:", max(values), "\n")
# Out:
# Alpha:	 0.0001
# Solver:	adam
# Learning rate:	constant
# Median: 0.246599948678
# Average: 0.251534727437
# Min: 0.223664503245
# Max: 0.298391281785
#
# Learning rate:	adaptive
# Median: 0.257264957265
# Average: 0.248464341857
# Min: 0.207892700542
# Max: 0.26766004415
#
# Learning rate:	invscaling
# Median: 0.261464403344
# Average: 0.251063405793
# Min: 0.20748116254
# Max: 0.289089994972
#
# Solver:	lbfgs
# Learning rate:	constant
# Median: 0.244052616849
# Average: 0.243575092749
# Min: 0.233045299817
# Max: 0.255561047949
#
# Learning rate:	adaptive
# Median: 0.215318285569
# Average: 0.225496741696
# Min: 0.200164293538
# Max: 0.265101556318
#
# Learning rate:	invscaling
# Median: 0.25332508506
# Average: 0.215784144789
# Min: 0.0722784057109
# Max: 0.266611524676
#
# Solver:	sgd
# Learning rate:	constant
# Median: 0.262543137775
# Average: 0.24082354489
# Min: 0.189726381002
# Max: 0.264843965755
#
# Learning rate:	adaptive
# Median: 0.268542199488
# Average: 0.270128515227
# Min: 0.26125193999
# Max: 0.282470017862
#
# Learning rate:	invscaling
# Median: 0.22896814593
# Average: 0.204069899572
# Min: 0.068108974359
# Max: 0.259248719408
#
# Alpha:	 0.001
# Solver:	adam
# Learning rate:	constant
# Median: 0.245121230041
# Average: 0.253489059292
# Min: 0.241011235955
# Max: 0.277720474471
#
# Learning rate:	adaptive
# Median: 0.26673479816
# Average: 0.262231746466
# Min: 0.248412698413
# Max: 0.272796545593
#
# Learning rate:	invscaling
# Median: 0.269735006974
# Average: 0.259890278465
# Min: 0.203366058906
# Max: 0.281886387996
#
# Solver:	lbfgs
# Learning rate:	constant
# Median: 0.241787829833
# Average: 0.243997268717
# Min: 0.218351741716
# Max: 0.272676683361
#
# Learning rate:	adaptive
# Median: 0.265559137119
# Average: 0.265655868632
# Min: 0.251915144372
# Max: 0.289080911233
#
# Learning rate:	invscaling
# Median: 0.267134831461
# Average: 0.247736278265
# Min: 0.203995793901
# Max: 0.280434220729
#
# Solver:	sgd
# Learning rate:	constant
# Median: 0.226046750578
# Average: 0.235763800851
# Min: 0.208010680908
# Max: 0.275204359673
#
# Learning rate:	adaptive
# Median: 0.260858050847
# Average: 0.242181662516
# Min: 0.183029643731
# Max: 0.262652478588
#
# Learning rate:	invscaling
# Median: 0.24638502977
# Average: 0.235190410797
# Min: 0.173065386923
# Max: 0.260045489007
#
# Alpha:	 0.01
# Solver:	adam
# Learning rate:	constant
# Median: 0.203934740883
# Average: 0.19730911336
# Min: 0.0707298720843
# Max: 0.272116461366
#
# Learning rate:	adaptive
# Median: 0.243946888831
# Average: 0.238583791695
# Min: 0.202491309386
# Max: 0.26487845767
#
# Learning rate:	invscaling
# Median: 0.271218206158
# Average: 0.263246602601
# Min: 0.241304933944
# Max: 0.272580210299
#
# Solver:	lbfgs
# Learning rate:	constant
# Median: 0.247839420128
# Average: 0.244567469816
# Min: 0.208450704225
# Max: 0.262145748988
#
# Learning rate:	adaptive
# Median: 0.264043419267
# Average: 0.259150793822
# Min: 0.232478632479
# Max: 0.271286596831
#
# Learning rate:	invscaling
# Median: 0.248252725748
# Average: 0.250184123989
# Min: 0.239075981074
# Max: 0.266516092603
#
# Solver:	sgd
# Learning rate:	constant
# Median: 0.275726392252
# Average: 0.255829672895
# Min: 0.200599618425
# Max: 0.281564908121
#
# Learning rate:	adaptive
# Median: 0.255645386117
# Average: 0.249370440604
# Min: 0.194006716611
# Max: 0.279238440617
#
# Learning rate:	invscaling
# Median: 0.258299595142
# Average: 0.250641114855
# Min: 0.226405228758
# Max: 0.275843158761
#
# Alpha:	 0.1
# Solver:	adam
# Learning rate:	constant
# Median: 0.262246993253
# Average: 0.263414864451
# Min: 0.241935483871
# Max: 0.280778164925
#
# Learning rate:	adaptive
# Median: 0.271047227926
# Average: 0.262236054351
# Min: 0.23918128655
# Max: 0.274689692391
#
# Learning rate:	invscaling
# Median: 0.240136830103
# Average: 0.232849398567
# Min: 0.195744680851
# Max: 0.261848651479
#
# Solver:	lbfgs
# Learning rate:	constant
# Median: 0.251037851038
# Average: 0.254418953586
# Min: 0.243128964059
# Max: 0.275563258232
#
# Learning rate:	adaptive
# Median: 0.229588276343
# Average: 0.228270048201
# Min: 0.196243875885
# Max: 0.262065386611
#
# Learning rate:	invscaling
# Median: 0.267934312878
# Average: 0.26756831438
# Min: 0.257668711656
# Max: 0.278280542986
#
# Solver:	sgd
# Learning rate:	constant
# Median: 0.247714285714
# Average: 0.243860342352
# Min: 0.214709677419
# Max: 0.283116095787
#
# Learning rate:	adaptive
# Median: 0.260213874417
# Average: 0.255524907962
# Min: 0.233694217058
# Max: 0.273917691074
#
# Learning rate:	invscaling
# Median: 0.262389867841
# Average: 0.261830469193
# Min: 0.23850039883
# Max: 0.278934221482

# %%
from sklearn.ensemble import RandomForestClassifier

criterions = [ "gini", "entropy"]
estimators_size = [50, 100, 150, 200]

for criterion in criterions:
    for n_estimators in estimators_size:
        values = []
        printf("RFC\t%d estimators\t%s criterion\n", n_estimators, criterion)
        for i in range(0, 5):
            X_train, y_train, X_test, y_test = createTrainTestSplit()
            rfc = RandomForestClassifier(n_estimators=n_estimators, max_features='log2', criterion=criterion)
            rfc.fit(X_train, y_train)
            values.append(rfc.score(X_test, y_test))
        
        values.sort()
        print("Median:", values[2])
        print("Average:", sum(values) / 5)
        print("Min:", min(values))
        print("Max:", max(values), "\n")
# Out:
# RFC	50 estimators	gini criterion
# Median: 0.68532526475
# Average: 0.695277865318
# Min: 0.675807278319
# Max: 0.736037788275
#
# RFC	100 estimators	gini criterion
# Median: 0.702797202797
# Average: 0.693885194043
# Min: 0.646305991856
# Max: 0.723763225622
#
# RFC	150 estimators	gini criterion
# Median: 0.678713858425
# Average: 0.677775439165
# Min: 0.647689375893
# Max: 0.711288711289
#
# RFC	200 estimators	gini criterion
# Median: 0.679077521534
# Average: 0.691873134892
# Min: 0.659303534304
# Max: 0.732016925247
#
# RFC	50 estimators	entropy criterion
# Median: 0.689740761169
# Average: 0.684652396595
# Min: 0.642140468227
# Max: 0.722823286965
#
# RFC	100 estimators	entropy criterion
# Median: 0.678914176035
# Average: 0.683431585801
# Min: 0.646781009197
# Max: 0.710540254237
#
# RFC	150 estimators	entropy criterion
# Median: 0.704579025111
# Average: 0.693454764829
# Min: 0.631990794016
# Max: 0.735854189336
#
# RFC	200 estimators	entropy criterion
# Median: 0.666390041494
# Average: 0.678228564773
# Min: 0.642522269105
# Max: 0.73652856756

# %%
from sklearn import tree
export_dtc = tree.DecisionTreeClassifier(max_depth=25)
export_dtc.fit(X_train, y_train)
print (export_dtc.score(X_test, y_test))
# Out:
# 0.616320885201

# %%
import sklearn.tree

tree.export_graphviz(dtc, 'tree.dot')

# %%
from collections import Counter
class Ensemble:
    
    def __init__(self, clfs):
        self.clfs = clfs
        
    def fit(self, X, y):
        for clf in self.clfs:
            clf.fit(X, y)
            
    def predict(self, X):
        predictions = []
        for clf in clfs:
            predictions.append(clf.predict(X))
            
        final_predictions = []
        
        temp = []
        for i in range(len(X)):
            values = []
            for j in range(len(self.clfs)):
                values.append(predictions[j][i])
            temp.append(values)

        for tmp in temp:
            final_predictions.append(Counter(tmp).most_common(1)[0][0])
            
        return final_predictions

# %%
from sklearn.metrics import accuracy_score
clfs = []

clfs.append(tree.DecisionTreeClassifier())
clfs.append(RandomForestClassifier(n_estimators=150, max_features='log2', criterion="entropy"))
clfs.append(ExtraTreesClassifier(n_estimators=30))
clfs.append(KNeighborsClassifier(n_neighbors=1))

ens = Ensemble(clfs)

ens.fit(X_train, y_train)

# %%
import warnings
warnings.filterwarnings('ignore')

y_pred = ens.predict(X_test)
print ("Ensemble score: ", accuracy_score(y_pred, y_test))
# Out:
# Ensemble score:  0.660857538036
